# %% [markdown]
# ## Import Libs

# %%
# Data manipulation & analysis
import pandas as pd
import numpy as np

# Data visualization
import matplotlib.pyplot as plt
import seaborn as sns
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import plotly.express as px

pd.set_option('display.max_columns',100)

# %% [markdown]
# ## Phase 1: Data Preparation & Cleaning
# - ✅ 1. Load the Data
# - ✅ 2. Clean the Data
# - ✅ 3. Feature Engineering

# %% [markdown]
# ### ✅ 1. Load the Data

# %%
df = pd.read_csv("../data/sales dataset.csv")

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# 0      42420.0  South  FUR-BO-10001798        Furniture    Bookcases
# 1      42420.0  South  FUR-CH-10000454        Furniture       Chairs
# 2      90036.0   West  OFF-LA-10000240  Office Supplies       Labels
# 3      33311.0  South  FUR-TA-10000577        Furniture       Tables
# 4      33311.0  South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales
# 0                  Bush Somerset Collection Bookcase  261.9600
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4                     Eldon Fold 'N Roll Cart System   22.3680

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
#  17  Sales          9800 non-null   float64
# dtypes: float64(2), int64(1), object(15)
# memory usage: 1.3+ MB

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### ✅ 2. Clean the Data

# %%
# Drop null values
df.dropna(axis=0,inplace=True)
df.drop("Row ID",axis=1,inplace=True)

# %%
df
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1     CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2     CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3     US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4     US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# ...              ...         ...         ...             ...         ...
# 9795  CA-2017-125920  21/05/2017  28/05/2017  Standard Class    SH-19975
# 9796  CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
#
#          Customer Name    Segment        Country             City       State  \
# 0          Claire Gute   Consumer  United States        Henderson    Kentucky
# 1          Claire Gute   Consumer  United States        Henderson    Kentucky
# 2      Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3       Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4       Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# ...                ...        ...            ...              ...         ...
# 9795     Sally Hughsby  Corporate  United States          Chicago    Illinois
# 9796  Cindy Schnelling  Corporate  United States           Toledo        Ohio
# 9797  Cindy Schnelling  Corporate  United States           Toledo        Ohio
# 9798  Cindy Schnelling  Corporate  United States           Toledo        Ohio
# 9799  Cindy Schnelling  Corporate  United States           Toledo        Ohio
#
#       Postal Code   Region       Product ID         Category Sub-Category  \
# 0         42420.0    South  FUR-BO-10001798        Furniture    Bookcases
# 1         42420.0    South  FUR-CH-10000454        Furniture       Chairs
# 2         90036.0     West  OFF-LA-10000240  Office Supplies       Labels
# 3         33311.0    South  FUR-TA-10000577        Furniture       Tables
# 4         33311.0    South  OFF-ST-10000760  Office Supplies      Storage
# ...           ...      ...              ...              ...          ...
# 9795      60610.0  Central  OFF-BI-10003429  Office Supplies      Binders
# 9796      43615.0     East  OFF-AR-10001374  Office Supplies          Art
# 9797      43615.0     East  TEC-PH-10004977       Technology       Phones
# 9798      43615.0     East  TEC-PH-10000912       Technology       Phones
# 9799      43615.0     East  TEC-AC-10000487       Technology  Accessories
#
#                                            Product Name     Sales
# 0                     Bush Somerset Collection Bookcase  261.9600
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4                        Eldon Fold 'N Roll Cart System   22.3680
# ...                                                 ...       ...
# 9795  Cardinal HOLDit! Binder Insert Strips,Extra St...    3.7980
# 9796           BIC Brite Liner Highlighters, Chisel Tip   10.3680
# 9797                                        GE 30524EE4  235.1880
# 9798           Anker 24W Portable Micro USB Car Charger   26.3760
# 9799                SanDisk Cruzer 4 GB USB Flash Drive   10.3840
#
# [9789 rows x 17 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.drop_duplicates(inplace=True)
df.reset_index(inplace=True,drop=True)

# %%
df
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1     CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2     CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3     US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4     US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# ...              ...         ...         ...             ...         ...
# 9783  CA-2017-125920  21/05/2017  28/05/2017  Standard Class    SH-19975
# 9784  CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9785  CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9786  CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9787  CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
#
#          Customer Name    Segment        Country             City       State  \
# 0          Claire Gute   Consumer  United States        Henderson    Kentucky
# 1          Claire Gute   Consumer  United States        Henderson    Kentucky
# 2      Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3       Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4       Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# ...                ...        ...            ...              ...         ...
# 9783     Sally Hughsby  Corporate  United States          Chicago    Illinois
# 9784  Cindy Schnelling  Corporate  United States           Toledo        Ohio
# 9785  Cindy Schnelling  Corporate  United States           Toledo        Ohio
# 9786  Cindy Schnelling  Corporate  United States           Toledo        Ohio
# 9787  Cindy Schnelling  Corporate  United States           Toledo        Ohio
#
#       Postal Code   Region       Product ID         Category Sub-Category  \
# 0         42420.0    South  FUR-BO-10001798        Furniture    Bookcases
# 1         42420.0    South  FUR-CH-10000454        Furniture       Chairs
# 2         90036.0     West  OFF-LA-10000240  Office Supplies       Labels
# 3         33311.0    South  FUR-TA-10000577        Furniture       Tables
# 4         33311.0    South  OFF-ST-10000760  Office Supplies      Storage
# ...           ...      ...              ...              ...          ...
# 9783      60610.0  Central  OFF-BI-10003429  Office Supplies      Binders
# 9784      43615.0     East  OFF-AR-10001374  Office Supplies          Art
# 9785      43615.0     East  TEC-PH-10004977       Technology       Phones
# 9786      43615.0     East  TEC-PH-10000912       Technology       Phones
# 9787      43615.0     East  TEC-AC-10000487       Technology  Accessories
#
#                                            Product Name     Sales
# 0                     Bush Somerset Collection Bookcase  261.9600
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4                        Eldon Fold 'N Roll Cart System   22.3680
# ...                                                 ...       ...
# 9783  Cardinal HOLDit! Binder Insert Strips,Extra St...    3.7980
# 9784           BIC Brite Liner Highlighters, Chisel Tip   10.3680
# 9785                                        GE 30524EE4  235.1880
# 9786           Anker 24W Portable Micro USB Car Charger   26.3760
# 9787                SanDisk Cruzer 4 GB USB Flash Drive   10.3840
#
# [9788 rows x 17 columns]

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'],format="mixed")
df['Ship Date'] = pd.to_datetime(df['Ship Date'],format="mixed")

# %% [markdown]
# ### ✅ 3. Feature Engineering

# %% [markdown]
# #### 1. Shipping Duration

# %%
df["ShippingDuration"] =  (df['Ship Date'] - df['Order Date']).dt.days

# %%
df.head()
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 1  CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 2  CA-2017-138688 2017-12-06 2017-06-16    Second Class    DV-13045
# 3  US-2016-108966 2016-11-10 2016-10-18  Standard Class    SO-20335
# 4  US-2016-108966 2016-11-10 2016-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# 0      42420.0  South  FUR-BO-10001798        Furniture    Bookcases
# 1      42420.0  South  FUR-CH-10000454        Furniture       Chairs
# 2      90036.0   West  OFF-LA-10000240  Office Supplies       Labels
# 3      33311.0  South  FUR-TA-10000577        Furniture       Tables
# 4      33311.0  South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  \
# 0                  Bush Somerset Collection Bookcase  261.9600
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4                     Eldon Fold 'N Roll Cart System   22.3680
#
#    ShippingDuration
# 0                92
# 1                92
# 2              -173
# 3               -23
# 4               -23

# %%
idx = df[df['Order Date']>df['Ship Date']].index.tolist()
df.drop(idx,axis=0,inplace=True)

# %%
df
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 1     CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 12    CA-2018-114412 2018-04-15 2018-04-20  Standard Class    AA-10480
# 13    CA-2017-161389 2017-05-12 2017-10-12  Standard Class    IM-15070
# 14    US-2016-118983 2016-11-22 2016-11-26  Standard Class    HP-14815
# ...              ...        ...        ...             ...         ...
# 9779  CA-2015-127166 2015-05-21 2015-05-23    Second Class    KH-16360
# 9780  CA-2015-127166 2015-05-21 2015-05-23    Second Class    KH-16360
# 9781  CA-2015-127166 2015-05-21 2015-05-23    Second Class    KH-16360
# 9782  CA-2015-127166 2015-05-21 2015-05-23    Second Class    KH-16360
# 9783  CA-2017-125920 2017-05-21 2017-05-28  Standard Class    SH-19975
#
#          Customer Name      Segment        Country        City  \
# 0          Claire Gute     Consumer  United States   Henderson
# 1          Claire Gute     Consumer  United States   Henderson
# 12        Andrew Allen     Consumer  United States     Concord
# 13        Irene Maddox     Consumer  United States     Seattle
# 14       Harold Pawlan  Home Office  United States  Fort Worth
# ...                ...          ...            ...         ...
# 9779  Katherine Hughes     Consumer  United States     Houston
# 9780  Katherine Hughes     Consumer  United States     Houston
# 9781  Katherine Hughes     Consumer  United States     Houston
# 9782  Katherine Hughes     Consumer  United States     Houston
# 9783     Sally Hughsby    Corporate  United States     Chicago
#
#                State  Postal Code   Region       Product ID         Category  \
# 0           Kentucky      42420.0    South  FUR-BO-10001798        Furniture
# 1           Kentucky      42420.0    South  FUR-CH-10000454        Furniture
# 12    North Carolina      28027.0    South  OFF-PA-10002365  Office Supplies
# 13        Washington      98103.0     West  OFF-BI-10003656  Office Supplies
# 14             Texas      76106.0  Central  OFF-AP-10002311  Office Supplies
# ...              ...          ...      ...              ...              ...
# 9779           Texas      77070.0  Central  OFF-EN-10003134  Office Supplies
# 9780           Texas      77070.0  Central  FUR-CH-10003396        Furniture
# 9781           Texas      77070.0  Central  OFF-PA-10001560  Office Supplies
# 9782           Texas      77070.0  Central  OFF-BI-10000977  Office Supplies
# 9783        Illinois      60610.0  Central  OFF-BI-10003429  Office Supplies
#
#      Sub-Category                                       Product Name    Sales  \
# 0       Bookcases                  Bush Somerset Collection Bookcase  261.960
# 1          Chairs  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.940
# 12          Paper                                         Xerox 1967   15.552
# 13        Binders        Fellowes PB200 Plastic Comb Binding Machine  407.976
# 14     Appliances  Holmes Replacement Filter for HEPA Air Cleaner...   68.810
# ...           ...                                                ...      ...
# 9779    Envelopes                                    Staple envelope   56.064
# 9780       Chairs                          Global Deluxe Steno Chair  107.772
# 9781        Paper        Adams Telephone Message Books, 5 1/4” x 11”    4.832
# 9782      Binders                 Ibico Plastic Spiral Binding Combs   18.240
# 9783      Binders  Cardinal HOLDit! Binder Insert Strips,Extra St...    3.798
#
#       ShippingDuration
# 0                   92
# 1                   92
# 12                   5
# 13                 153
# 14                   4
# ...                ...
# 9779                 2
# 9780                 2
# 9781                 2
# 9782                 2
# 9783                 7
#
# [8104 rows x 18 columns]

# %% [markdown]
# #### 2. Time-Based Features

# %%
df['year'] = df['Order Date'].dt.year
df['month'] = df['Order Date'].dt.month
df['day_of_week'] = df['Order Date'].dt.dayofweek
df['is_weekend'] = (df['day_of_week']>= 5).astype(int)
df['Quarter'] = df['month'].apply(lambda x:1 if x <=3 else round(x/3))

# %%
df.head()
# Out:
#           Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0   CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 1   CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 12  CA-2018-114412 2018-04-15 2018-04-20  Standard Class    AA-10480
# 13  CA-2017-161389 2017-05-12 2017-10-12  Standard Class    IM-15070
# 14  US-2016-118983 2016-11-22 2016-11-26  Standard Class    HP-14815
#
#     Customer Name      Segment        Country        City           State  \
# 0     Claire Gute     Consumer  United States   Henderson        Kentucky
# 1     Claire Gute     Consumer  United States   Henderson        Kentucky
# 12   Andrew Allen     Consumer  United States     Concord  North Carolina
# 13   Irene Maddox     Consumer  United States     Seattle      Washington
# 14  Harold Pawlan  Home Office  United States  Fort Worth           Texas
#
#     Postal Code   Region       Product ID         Category Sub-Category  \
# 0       42420.0    South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420.0    South  FUR-CH-10000454        Furniture       Chairs
# 12      28027.0    South  OFF-PA-10002365  Office Supplies        Paper
# 13      98103.0     West  OFF-BI-10003656  Office Supplies      Binders
# 14      76106.0  Central  OFF-AP-10002311  Office Supplies   Appliances
#
#                                          Product Name    Sales  \
# 0                   Bush Somerset Collection Bookcase  261.960
# 1   Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.940
# 12                                         Xerox 1967   15.552
# 13        Fellowes PB200 Plastic Comb Binding Machine  407.976
# 14  Holmes Replacement Filter for HEPA Air Cleaner...   68.810
#
#     ShippingDuration  year  month  day_of_week  is_weekend  Quarter
# 0                 92  2017      8            4           0        3
# 1                 92  2017      8            4           0        3
# 12                 5  2018      4            6           1        1
# 13               153  2017      5            4           0        2
# 14                 4  2016     11            1           0        4

# %%
df.is_weekend.value_counts()
# Out:
# is_weekend
# 0    5470
# 1    2634
# Name: count, dtype: int64

# %%
df['Quarter'] = df['Quarter'].apply(lambda x: round(x))
df.head()
# Out:
#           Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0   CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 1   CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 12  CA-2018-114412 2018-04-15 2018-04-20  Standard Class    AA-10480
# 13  CA-2017-161389 2017-05-12 2017-10-12  Standard Class    IM-15070
# 14  US-2016-118983 2016-11-22 2016-11-26  Standard Class    HP-14815
#
#     Customer Name      Segment        Country        City           State  \
# 0     Claire Gute     Consumer  United States   Henderson        Kentucky
# 1     Claire Gute     Consumer  United States   Henderson        Kentucky
# 12   Andrew Allen     Consumer  United States     Concord  North Carolina
# 13   Irene Maddox     Consumer  United States     Seattle      Washington
# 14  Harold Pawlan  Home Office  United States  Fort Worth           Texas
#
#     Postal Code   Region       Product ID         Category Sub-Category  \
# 0       42420.0    South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420.0    South  FUR-CH-10000454        Furniture       Chairs
# 12      28027.0    South  OFF-PA-10002365  Office Supplies        Paper
# 13      98103.0     West  OFF-BI-10003656  Office Supplies      Binders
# 14      76106.0  Central  OFF-AP-10002311  Office Supplies   Appliances
#
#                                          Product Name    Sales  \
# 0                   Bush Somerset Collection Bookcase  261.960
# 1   Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.940
# 12                                         Xerox 1967   15.552
# 13        Fellowes PB200 Plastic Comb Binding Machine  407.976
# 14  Holmes Replacement Filter for HEPA Air Cleaner...   68.810
#
#     ShippingDuration  year  month  day_of_week  is_weekend  Quarter
# 0                 92  2017      8            4           0        3
# 1                 92  2017      8            4           0        3
# 12                 5  2018      4            6           1        1
# 13               153  2017      5            4           0        2
# 14                 4  2016     11            1           0        4

# %%
df.isnull().sum()
# Out:
# Order ID            0
# Order Date          0
# Ship Date           0
# Ship Mode           0
# Customer ID         0
# Customer Name       0
# Segment             0
# Country             0
# City                0
# State               0
# Postal Code         0
# Region              0
# Product ID          0
# Category            0
# Sub-Category        0
# Product Name        0
# Sales               0
# ShippingDuration    0
# year                0
# month               0
# day_of_week         0
# is_weekend          0
# Quarter             0
# dtype: int64

# %% [markdown]
# **✅ Phase 1 Complete: Data cleaning and feature engineering are now finished. The dataset is fully prepared and ready for analysis.**
# **Next Step — Phase 2: Let’s move on to the analysis and insight generation stage.**
#
# ## Phase 2: Exploratory Data Analysis (EDA) & Visualization
# - ✅ 4. General Overview
# - ✅ 5. Top-Selling Products Analysis
# - ✅ 6. SEO Optimization
# - ✅ 7. Pricing Strategy

# %% [markdown]
# ### ✅ 4. General Overview

# %% [markdown]
# #### 1. Descriptive Stats

# %%
df.describe(exclude='O').T
# Out:
#                    count                           mean                  min  \
# Order Date          8104  2017-04-03 17:01:11.076011776  2015-01-02 00:00:00
# Ship Date           8104  2017-05-15 10:29:33.346495488  2015-01-15 00:00:00
# Postal Code       8104.0                   55436.663746               1040.0
# Sales             8104.0                     234.150872                0.444
# ShippingDuration  8104.0                      41.728036                  0.0
# year              8104.0                    2016.731491               2015.0
# month             8104.0                       6.819719                  1.0
# day_of_week       8104.0                       2.961007                  0.0
# is_weekend        8104.0                       0.325025                  0.0
# Quarter           8104.0                       2.355257                  1.0
#
#                                   25%                  50%  \
# Order Date        2016-04-18 00:00:00  2017-05-17 00:00:00
# Ship Date         2016-06-20 00:00:00  2017-07-12 00:00:00
# Postal Code                   23434.0              59601.0
# Sales                           17.22               54.432
# ShippingDuration                  4.0                  5.0
# year                           2016.0               2017.0
# month                             4.0                  7.0
# day_of_week                       1.0                  3.0
# is_weekend                        0.0                  0.0
# Quarter                           1.0                  2.0
#
#                                   75%                  max           std
# Order Date        2018-03-28 00:00:00  2018-12-30 00:00:00           NaN
# Ship Date         2018-06-01 00:00:00  2019-05-01 00:00:00           NaN
# Postal Code                   90005.0              99301.0  31937.147511
# Sales                         210.995             22638.48    661.643335
# ShippingDuration                 89.0                214.0     58.041509
# year                           2018.0               2018.0      1.124691
# month                            10.0                 12.0      3.443728
# day_of_week                       5.0                  6.0      2.121442
# is_weekend                        1.0                  1.0      0.468413
# Quarter                           3.0                  4.0      1.112028

# %%
df.describe(include='O').T
# Out:
#               count unique              top  freq
# Order ID       8104   4040   CA-2018-100111    14
# Ship Mode      8104      4   Standard Class  4628
# Customer ID    8104    791         MA-17560    34
# Customer Name  8104    791     Matt Abelman    34
# Segment        8104      3         Consumer  4231
# Country        8104      1    United States  8104
# City           8104    506    New York City   762
# State          8104     48       California  1640
# Region         8104      4             West  2603
# Product ID     8104   1839  TEC-AC-10002049    15
# Category       8104      3  Office Supplies  4889
# Sub-Category   8104     17          Binders  1265
# Product Name   8104   1826  Staple envelope    39

# %% [markdown]
# #### 2. Outliers Detection

# %%
Q1 = df['Sales'].quantile(0.25)
Q3 = df['Sales'].quantile(0.75)
IQR = Q3 - Q1

outs = df[(df['Sales'] < Q1 - 1.5*IQR) | (df['Sales'] > Q3 + 1.5*IQR)]
outs
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 1     CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 16    CA-2015-105893 2015-11-11 2015-11-18  Standard Class    PK-19075
# 24    CA-2016-106320 2016-09-25 2016-09-30  Standard Class    EB-13870
# 27    US-2016-150630 2016-09-17 2016-09-21  Standard Class    TB-21520
# 35    CA-2017-117590 2017-08-12 2017-10-12     First Class    GH-14485
# ...              ...        ...        ...             ...         ...
# 9716  CA-2018-167395 2018-02-12 2018-04-12     First Class    KM-16720
# 9723  CA-2015-114321 2015-08-20 2015-08-25  Standard Class    NC-18535
# 9736  US-2015-140914 2015-11-11 2015-11-15  Standard Class    BH-11710
# 9762  CA-2015-169019 2015-07-26 2015-07-30  Standard Class    LF-17185
# 9769  CA-2017-153178 2017-09-14 2017-09-18  Standard Class    CL-12565
#
#         Customer Name    Segment        Country          City          State  \
# 1         Claire Gute   Consumer  United States     Henderson       Kentucky
# 16          Pete Kriz   Consumer  United States       Madison      Wisconsin
# 24        Emily Burns   Consumer  United States          Orem           Utah
# 27    Tracy Blumstein   Consumer  United States  Philadelphia   Pennsylvania
# 35          Gene Hale  Corporate  United States    Richardson          Texas
# ...               ...        ...            ...           ...            ...
# 9716     Kunst Miller   Consumer  United States        Lowell  Massachusetts
# 9723    Nick Crebassa  Corporate  United States       Hampton       Virginia
# 9736  Brosina Hoffman   Consumer  United States       Chicago       Illinois
# 9762      Luke Foster   Consumer  United States   San Antonio          Texas
# 9769      Clay Ludtke   Consumer  United States    Long Beach       New York
#
#       Postal Code   Region       Product ID         Category Sub-Category  \
# 1         42420.0    South  FUR-CH-10000454        Furniture       Chairs
# 16        53711.0  Central  OFF-ST-10004186  Office Supplies      Storage
# 24        84057.0     West  FUR-TA-10000577        Furniture       Tables
# 27        19140.0     East  FUR-BO-10004834        Furniture    Bookcases
# 35        75080.0  Central  TEC-PH-10004977       Technology       Phones
# ...           ...      ...              ...              ...          ...
# 9716       1852.0     East  TEC-PH-10004977       Technology       Phones
# 9723      23666.0    South  OFF-BI-10001359  Office Supplies      Binders
# 9736      60653.0  Central  FUR-CH-10003379        Furniture       Chairs
# 9762      78207.0  Central  OFF-BI-10004995  Office Supplies      Binders
# 9769      11561.0     East  OFF-BI-10004390  Office Supplies      Binders
#
#                                            Product Name     Sales  \
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...   731.940
# 16    Stur-D-Stor Shelving, Vertical 5-Shelf: 72"H x...   665.880
# 24        Bretford CR4500 Series Slim Rectangular Table  1044.630
# 27    Riverside Palais Royal Lawyers Bookcase, Royal...  3083.430
# 35                                          GE 30524EE4  1097.544
# ...                                                 ...       ...
# 9716                                        GE 30524EE4   979.950
# 9723         GBC DocuBind TL300 Electric Binding System   896.990
# 9736  Global Commerce Series High-Back Swivel/Tilt C...   797.944
# 9762          GBC DocuBind P400 Electric Binding System  2177.584
# 9769            GBC DocuBind 200 Manual Binding Machine   673.568
#
#       ShippingDuration  year  month  day_of_week  is_weekend  Quarter
# 1                   92  2017      8            4           0        3
# 16                   7  2015     11            2           0        4
# 24                   5  2016      9            6           1        3
# 27                   4  2016      9            5           1        3
# 35                  61  2017      8            5           1        3
# ...                ...   ...    ...          ...         ...      ...
# 9716                59  2018      2            0           0        1
# 9723                 5  2015      8            3           0        3
# 9736                 4  2015     11            2           0        4
# 9762                 4  2015      7            6           1        2
# 9769                 4  2017      9            3           0        3
#
# [934 rows x 23 columns]

# %%
outs.describe().T
# Out:
#                   count                           mean                  min  \
# Order Date          934  2017-03-12 14:44:58.072805120  2015-01-03 00:00:00
# Ship Date           934  2017-04-20 14:21:50.492505344  2015-01-15 00:00:00
# Postal Code       934.0                   53640.785867               1841.0
# Sales             934.0                    1314.060997               501.81
# ShippingDuration  934.0                       38.98394                  0.0
# year              934.0                    2016.649893               2015.0
# month             934.0                       7.068522                  1.0
# day_of_week       934.0                       2.889722                  0.0
# is_weekend        934.0                       0.316916                  0.0
# Quarter           934.0                       2.443255                  1.0
#
#                                   25%                  50%  \
# Order Date        2016-03-12 06:00:00  2017-03-19 00:00:00
# Ship Date         2016-05-11 00:00:00  2017-06-06 00:00:00
# Postal Code                   21044.0              53142.0
# Sales                         637.005              879.984
# ShippingDuration                  3.0                  5.0
# year                           2016.0               2017.0
# month                             4.0                  8.0
# day_of_week                       1.0                  3.0
# is_weekend                        0.0                  0.0
# Quarter                           1.0                  3.0
#
#                                   75%                  max           std
# Order Date        2018-03-10 18:00:00  2018-12-29 00:00:00           NaN
# Ship Date         2018-05-17 00:00:00  2019-02-01 00:00:00           NaN
# Postal Code                   90008.0              99301.0  32812.904437
# Sales                        1362.165             22638.48   1543.039581
# ShippingDuration                61.75                214.0     56.061985
# year                           2018.0               2018.0      1.134339
# month                            10.0                 12.0      3.493926
# day_of_week                       5.0                  6.0      2.111481
# is_weekend                        1.0                  1.0      0.465524
# Quarter                           3.0                  4.0      1.123887

# %% [markdown]
# ### ✅ 5. Univariate Analysis

# %% [markdown]
# #### 1. Numeric Features

# %%
df.select_dtypes(include='number').columns
# Out:
# Index(['Postal Code', 'Sales', 'ShippingDuration', 'year', 'month',
#        'day_of_week', 'is_weekend', 'Quarter'],
#       dtype='object')

# %%
fig = make_subplots(rows=2,cols=2,
                   subplot_titles=['Sales Distribution','Shipping Duration Distribution',
                                  'Sales Box Plot','Shipping Duration Box Plot'])

fig.add_trace(go.Histogram(x=df['Sales'],
                          histnorm='probability density',
                          opacity=0.7),row=1,col=1)

fig.add_trace(go.Box(x=df['Sales'],),row=2,col=1)

fig.add_trace(go.Histogram(x=df['ShippingDuration'],
                          histnorm='probability density',
                          opacity=0.7),row=1,col=2)

fig.add_trace(go.Box(x=df['ShippingDuration'],),row=2,col=2)
fig.update_layout(
    width=1400,
    height=600
)

fig.show()

# %%
df['Sales'].skew()
# Out:
# np.float64(13.090426328209436)

# %%
(df['Sales'] == 0).any()
# Out:
# np.False_

# %%
df['is_weekend'].value_counts(normalize=True)
# Out:
# is_weekend
# 0    0.674975
# 1    0.325025
# Name: proportion, dtype: float64

# %% [markdown]
# #### 2. Categorical Features

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'ShippingDuration', 'year', 'month', 'day_of_week',
#        'is_weekend', 'Quarter'],
#       dtype='object')

# %%
df['Order ID'].value_counts().head(10)
# Out:
# Order ID
# CA-2018-100111    14
# CA-2018-157987    12
# US-2017-108504    11
# CA-2017-165330    11
# CA-2017-105732    10
# CA-2016-131338    10
# US-2016-126977    10
# CA-2016-158421     9
# US-2016-163433     9
# US-2017-114013     9
# Name: count, dtype: int64

# %%
df[df['Order ID']=='CA-2018-100111']
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 6087  CA-2018-100111 2018-09-20 2018-09-26  Standard Class    SV-20365
# 6088  CA-2018-100111 2018-09-20 2018-09-26  Standard Class    SV-20365
# 6089  CA-2018-100111 2018-09-20 2018-09-26  Standard Class    SV-20365
# 6090  CA-2018-100111 2018-09-20 2018-09-26  Standard Class    SV-20365
# 6091  CA-2018-100111 2018-09-20 2018-09-26  Standard Class    SV-20365
# 6092  CA-2018-100111 2018-09-20 2018-09-26  Standard Class    SV-20365
# 6093  CA-2018-100111 2018-09-20 2018-09-26  Standard Class    SV-20365
# 6094  CA-2018-100111 2018-09-20 2018-09-26  Standard Class    SV-20365
# 6095  CA-2018-100111 2018-09-20 2018-09-26  Standard Class    SV-20365
# 6096  CA-2018-100111 2018-09-20 2018-09-26  Standard Class    SV-20365
# 6097  CA-2018-100111 2018-09-20 2018-09-26  Standard Class    SV-20365
# 6098  CA-2018-100111 2018-09-20 2018-09-26  Standard Class    SV-20365
# 6099  CA-2018-100111 2018-09-20 2018-09-26  Standard Class    SV-20365
# 6100  CA-2018-100111 2018-09-20 2018-09-26  Standard Class    SV-20365
#
#      Customer Name   Segment        Country           City     State  \
# 6087   Seth Vernon  Consumer  United States  New York City  New York
# 6088   Seth Vernon  Consumer  United States  New York City  New York
# 6089   Seth Vernon  Consumer  United States  New York City  New York
# 6090   Seth Vernon  Consumer  United States  New York City  New York
# 6091   Seth Vernon  Consumer  United States  New York City  New York
# 6092   Seth Vernon  Consumer  United States  New York City  New York
# 6093   Seth Vernon  Consumer  United States  New York City  New York
# 6094   Seth Vernon  Consumer  United States  New York City  New York
# 6095   Seth Vernon  Consumer  United States  New York City  New York
# 6096   Seth Vernon  Consumer  United States  New York City  New York
# 6097   Seth Vernon  Consumer  United States  New York City  New York
# 6098   Seth Vernon  Consumer  United States  New York City  New York
# 6099   Seth Vernon  Consumer  United States  New York City  New York
# 6100   Seth Vernon  Consumer  United States  New York City  New York
#
#       Postal Code Region       Product ID         Category Sub-Category  \
# 6087      10035.0   East  FUR-CH-10003846        Furniture       Chairs
# 6088      10035.0   East  TEC-AC-10002647       Technology  Accessories
# 6089      10035.0   East  OFF-PA-10000807  Office Supplies        Paper
# 6090      10035.0   East  TEC-AC-10001465       Technology  Accessories
# 6091      10035.0   East  OFF-ST-10000615  Office Supplies      Storage
# 6092      10035.0   East  OFF-PA-10002713  Office Supplies        Paper
# 6093      10035.0   East  FUR-CH-10003061        Furniture       Chairs
# 6094      10035.0   East  OFF-BI-10000343  Office Supplies      Binders
# 6095      10035.0   East  OFF-FA-10000304  Office Supplies    Fasteners
# 6096      10035.0   East  FUR-CH-10004086        Furniture       Chairs
# 6097      10035.0   East  TEC-PH-10002885       Technology       Phones
# 6098      10035.0   East  FUR-CH-10001215        Furniture       Chairs
# 6099      10035.0   East  TEC-PH-10000215       Technology       Phones
# 6100      10035.0   East  TEC-AC-10001998       Technology  Accessories
#
#                                            Product Name     Sales  \
# 6087                         Hon Valutask Swivel Chairs   272.646
# 6088  Logitech Wireless Boombox Speaker - portable -...   212.800
# 6089  TOPS "Important Message" Pads, Canary, 4-1/4 x...    38.520
# 6090               SanDisk Cruzer 64 GB USB Flash Drive    72.640
# 6091  SimpliFile Personal File, Black Granite, 15w x...    45.400
# 6092  Adams Phone Message Book, 200 Message Capacity...    13.760
# 6093                   Global Leather Task Chair, Black    80.991
# 6094  Pressboard Covers with Storage Hooks, 9 1/2" x...    11.784
# 6095                                 Advantus Push Pins     4.360
# 6096  Hon 4070 Series Pagoda Armless Upholstered Sta...  2888.127
# 6097                                     Apple iPhone 5  1299.660
# 6098      Global Troy Executive Leather Low-Back Tilter  2254.410
# 6099  Plantronics Cordless Phone Headset with In-lin...   104.850
# 6100  Logitech LS21 Speaker System - PC Multimedia -...    59.970
#
#       ShippingDuration  year  month  day_of_week  is_weekend  Quarter
# 6087                 6  2018      9            3           0        3
# 6088                 6  2018      9            3           0        3
# 6089                 6  2018      9            3           0        3
# 6090                 6  2018      9            3           0        3
# 6091                 6  2018      9            3           0        3
# 6092                 6  2018      9            3           0        3
# 6093                 6  2018      9            3           0        3
# 6094                 6  2018      9            3           0        3
# 6095                 6  2018      9            3           0        3
# 6096                 6  2018      9            3           0        3
# 6097                 6  2018      9            3           0        3
# 6098                 6  2018      9            3           0        3
# 6099                 6  2018      9            3           0        3
# 6100                 6  2018      9            3           0        3

# %%
df[df['Order ID']=='CA-2018-157987']
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 1946  CA-2018-157987 2018-02-09 2018-06-09  Standard Class    AC-10615
# 1947  CA-2018-157987 2018-02-09 2018-06-09  Standard Class    AC-10615
# 1948  CA-2018-157987 2018-02-09 2018-06-09  Standard Class    AC-10615
# 1949  CA-2018-157987 2018-02-09 2018-06-09  Standard Class    AC-10615
# 1950  CA-2018-157987 2018-02-09 2018-06-09  Standard Class    AC-10615
# 1951  CA-2018-157987 2018-02-09 2018-06-09  Standard Class    AC-10615
# 1952  CA-2018-157987 2018-02-09 2018-06-09  Standard Class    AC-10615
# 1953  CA-2018-157987 2018-02-09 2018-06-09  Standard Class    AC-10615
# 1954  CA-2018-157987 2018-02-09 2018-06-09  Standard Class    AC-10615
# 1955  CA-2018-157987 2018-02-09 2018-06-09  Standard Class    AC-10615
# 1956  CA-2018-157987 2018-02-09 2018-06-09  Standard Class    AC-10615
# 1957  CA-2018-157987 2018-02-09 2018-06-09  Standard Class    AC-10615
#
#      Customer Name    Segment        Country           City     State  \
# 1946     Ann Chong  Corporate  United States  New York City  New York
# 1947     Ann Chong  Corporate  United States  New York City  New York
# 1948     Ann Chong  Corporate  United States  New York City  New York
# 1949     Ann Chong  Corporate  United States  New York City  New York
# 1950     Ann Chong  Corporate  United States  New York City  New York
# 1951     Ann Chong  Corporate  United States  New York City  New York
# 1952     Ann Chong  Corporate  United States  New York City  New York
# 1953     Ann Chong  Corporate  United States  New York City  New York
# 1954     Ann Chong  Corporate  United States  New York City  New York
# 1955     Ann Chong  Corporate  United States  New York City  New York
# 1956     Ann Chong  Corporate  United States  New York City  New York
# 1957     Ann Chong  Corporate  United States  New York City  New York
#
#       Postal Code Region       Product ID         Category Sub-Category  \
# 1946      10009.0   East  OFF-AR-10000658  Office Supplies          Art
# 1947      10009.0   East  FUR-FU-10001196        Furniture  Furnishings
# 1948      10009.0   East  FUR-TA-10001889        Furniture       Tables
# 1949      10009.0   East  OFF-AP-10000358  Office Supplies   Appliances
# 1950      10009.0   East  OFF-BI-10004970  Office Supplies      Binders
# 1951      10009.0   East  TEC-PH-10003885       Technology       Phones
# 1952      10009.0   East  OFF-LA-10001641  Office Supplies       Labels
# 1953      10009.0   East  FUR-CH-10003379        Furniture       Chairs
# 1954      10009.0   East  OFF-AR-10004582  Office Supplies          Art
# 1955      10009.0   East  TEC-AC-10002842       Technology  Accessories
# 1956      10009.0   East  TEC-AC-10000109       Technology  Accessories
# 1957      10009.0   East  OFF-PA-10003893  Office Supplies        Paper
#
#                                            Product Name     Sales  \
# 1946                                         Newell 324    23.100
# 1947                          DAX Cubicle Frames - 8x10    11.540
# 1948  Bush Advantage Collection Racetrack Conference...   254.526
# 1949  Fellowes Basic Home/Office Series Surge Protec...    12.980
# 1950                   ACCOHIDE 3-Ring Binder, Blue, 1"    26.432
# 1951                                      Cisco SPA508G   197.970
# 1952                                          Avery 518    18.900
# 1953  Global Commerce Series High-Back Swivel/Tilt C...  1282.410
# 1954                  BIC Brite Liner Grip Highlighters     4.920
# 1955  WD My Passport Ultra 2TB Portable External Har...   238.000
# 1956   Sony Micro Vault Click 16 GB USB 2.0 Flash Drive   167.970
# 1957                                         Xerox 1962    17.120
#
#       ShippingDuration  year  month  day_of_week  is_weekend  Quarter
# 1946               120  2018      2            4           0        1
# 1947               120  2018      2            4           0        1
# 1948               120  2018      2            4           0        1
# 1949               120  2018      2            4           0        1
# 1950               120  2018      2            4           0        1
# 1951               120  2018      2            4           0        1
# 1952               120  2018      2            4           0        1
# 1953               120  2018      2            4           0        1
# 1954               120  2018      2            4           0        1
# 1955               120  2018      2            4           0        1
# 1956               120  2018      2            4           0        1
# 1957               120  2018      2            4           0        1

# %%
df['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Standard Class    4628
# Second Class      1596
# First Class       1344
# Same Day           536
# Name: count, dtype: int64

# %%
df['Segment'].value_counts(normalize=True)
# Out:
# Segment
# Consumer       0.522088
# Corporate      0.300592
# Home Office    0.177320
# Name: proportion, dtype: float64

# %%
df['State'].value_counts()
# Out:
# State
# California              1640
# New York                 924
# Texas                    822
# Pennsylvania             476
# Illinois                 396
# Ohio                     394
# Washington               392
# Florida                  303
# Michigan                 209
# North Carolina           205
# Arizona                  190
# Virginia                 189
# Tennessee                160
# Georgia                  149
# Colorado                 143
# Kentucky                 109
# Massachusetts            108
# Indiana                  102
# Oregon                    95
# Wisconsin                 90
# New Jersey                83
# Maryland                  81
# Minnesota                 77
# Delaware                  71
# Connecticut               62
# Arkansas                  53
# Oklahoma                  52
# Alabama                   51
# Missouri                  50
# Utah                      49
# Mississippi               44
# Rhode Island              41
# South Carolina            37
# Nebraska                  35
# New Mexico                32
# Louisiana                 31
# Nevada                    29
# New Hampshire             26
# Iowa                      22
# Idaho                     20
# Kansas                    17
# Montana                   12
# South Dakota              12
# Maine                      8
# North Dakota               7
# West Virginia              4
# District of Columbia       1
# Wyoming                    1
# Name: count, dtype: int64

# %%
df['Region'].value_counts()
# Out:
# Region
# West       2603
# East       2279
# Central    1891
# South      1331
# Name: count, dtype: int64

# %%
df['Category'].value_counts(normalize=True)
# Out:
# Category
# Office Supplies    0.603282
# Furniture          0.212734
# Technology         0.183983
# Name: proportion, dtype: float64

# %%
df['Sub-Category'].value_counts()
# Out:
# Sub-Category
# Binders        1265
# Paper          1098
# Furnishings     767
# Phones          712
# Storage         686
# Art             655
# Accessories     624
# Chairs          509
# Appliances      378
# Labels          285
# Tables          263
# Envelopes       194
# Bookcases       185
# Fasteners       169
# Supplies        159
# Machines        101
# Copiers          54
# Name: count, dtype: int64

# %% [markdown]
# ### ✅ 6. Bivariate Analysis

# %% [markdown]
# #### 1️⃣ Sales vs Categorical Variables

# %% [markdown]
# ##### 1. Top 10 States On Sales

# %%
top_States = df['State'].value_counts().head(10).index.tolist()
fig = px.histogram(
    data_frame=df[df['State'].isin(top_States)],
    x = 'State',
    y='Sales',
    color='Category',
    text_auto=True,
    title='Top 10 States On Sales'

)
fig.show()

# %% [markdown]
# ##### 2. Top 10 Products on Sales

# %%
top_States = df['Product Name'].value_counts().head(10).index.tolist()
fig = px.histogram(
    data_frame=df[df['Product Name'].isin(top_States)],
    x = 'Product Name',
    y='Sales',
    color='Category',
    text_auto=True,
    title='Top 10 Products On Sales'

)
fig.show()

# %% [markdown]
# ##### 3. Sales by Category

# %%
fig = px.histogram(
    data_frame=df,
    x = 'Category',
    y = 'Sales',
    text_auto=True,
    title='Sales By Category',
    color='Category'
)
fig.show()

# %% [markdown]
# ##### 4. Sales by Sub-Category

# %%
fig = px.histogram(
    data_frame=df,
    x = 'Sub-Category',
    y = 'Sales',
    text_auto=True,
    title='Sales by Sub-Category',
    color='Sub-Category'
)
fig.show()

# %% [markdown]
# ##### 5. Sales by Segment

# %%
fig = px.histogram(
    data_frame=df,
    x = 'Segment',
    y = 'Sales',
    text_auto=True,
    title='Sales by Segment',
    color='Segment'
)
fig.show()

# %% [markdown]
# ##### 6. Sales by Ship Mode

# %%
fig = px.histogram(
    data_frame=df,
    x = 'Ship Mode',
    y = 'Sales',
    text_auto=True,
    title='Sales by Ship Mode',
    color='Ship Mode'
)
fig.show()

# %% [markdown]
# ##### 7. Sales by Region

# %%
fig = px.histogram(
    data_frame=df,
    x = 'Region',
    y = 'Sales',
    text_auto=True,
    title='Sales by Region',
    color='Region'
)
fig.show()

# %% [markdown]
# #### 2️⃣ Sales vs Time (Trend / Seasonality)

# %% [markdown]
# ##### 1. Sales over Time

# %%
fig = px.line(
    data_frame=df.groupby(['Order Date'],as_index=False)['Sales'].sum(),
    x = 'Order Date',
    y = 'Sales',
    title='Sales Over Time',
)
fig.show()

# %% [markdown]
# ##### 2. Sales by Year

# %%
fig = px.line(
    data_frame=df.groupby(['year'],as_index=False)['Sales'].sum(),
    x = 'year',
    y = 'Sales',
    title='Sales by Year',
)
fig.show()

# %% [markdown]
# ##### 3. Sales by Month

# %%
monthly_sales = (
    df.groupby(['year', 'month'], as_index=False)['Sales']
      .sum()
)

fig = make_subplots(
    rows=2,
    cols=2,
    subplot_titles=[
        'Monthly Trend Sales 2015',
        'Monthly Trend Sales 2016',
        'Monthly Trend Sales 2017',
        'Monthly Trend Sales 2018'
    ]
)

years = [2015, 2016, 2017, 2018]
positions = [(1,1), (1,2), (2,1), (2,2)]

for year, (r, c) in zip(years, positions):
    data = monthly_sales[monthly_sales['year'] == year]

    fig.add_trace(
        go.Scatter(
            x=data['month'],
            y=data['Sales'],
            mode='lines+markers',
            name=str(year)
        ),
        row=r,
        col=c
    )

fig.update_layout(
    width=1400,
    height=600,
    showlegend=False
)

fig.show()

# %% [markdown]
# ##### 4. Sales by Day of Week

# %%
df['week'] = df['Order Date'].dt.isocalendar().week
weekly_sales = df.groupby(['year','week'],as_index=False)['Sales'].sum()

fig = make_subplots(
    rows=2,
    cols=2,
    subplot_titles=[
        'Weekly Trends 2015',
        'Weekly Trends 2016',
        'Weekly Trends 2017',
        'Weekly Trends 2018'
    ]
)

years = [2015, 2016, 2017, 2018]
positions = [(1,1), (1,2), (2,1), (2,2)]

for year, (r, c) in zip(years, positions):
    data = weekly_sales[weekly_sales['year'] == year]

    fig.add_trace(
        go.Scatter(
            x=data['week'],
            y=data['Sales'],
            mode='lines+markers',
            name=str(year)
        ),
        row=r,
        col=c
    )

fig.update_layout(
    width=1400,
    height=600,
    showlegend=False
)

fig.show()

# %% [markdown]
# ##### 5. Weekend vs Weekday Sales

# %%
fig = px.box(data_frame=df,
            y = 'Sales',
            x = 'is_weekend',
            color='is_weekend',
            title='Weekend Vs Weekday')

fig.update_layout(
    width=800,
    height=750,
    showlegend=False
)

fig.show()

# %% [markdown]
# ##### 6. Sales by Quarter

# %%
Quarterly_sales = df.groupby(['year','Quarter'],as_index=False)['Sales'].sum()

fig = make_subplots(
    rows=2,
    cols=2,
    subplot_titles=[
        'Quarter Trends 2015',
        'Quarter Trends 2016',
        'Quarter Trends 2017',
        'Quarter Trends 2018'
    ]
)

years = [2015, 2016, 2017, 2018]
positions = [(1,1), (1,2), (2,1), (2,2)]

for year, (r, c) in zip(years, positions):
    data = Quarterly_sales[Quarterly_sales['year'] == year]

    fig.add_trace(
        go.Scatter(
            x=data['Quarter'],
            y=data['Sales'],
            mode='lines+markers',
            name=str(year)
        ),
        row=r,
        col=c
    )

fig.update_layout(
    width=1400,
    height=600,
    showlegend=False
)

fig.show()

# %% [markdown]
# **✅ Phase 2 Complete: General overview , Top-Selling,SEO and Pricing Stratigy.—>Phase 2:Let’s move on to Statistical & Business Analysis**
# ## Phase 3: Statistical & Business Analysis
# - ✅ 8. Correlation Matrix
# - ✅ 9. Business Insights

# %% [markdown]
# ### ✅ 7. Pricing Strategy

# %% [markdown]
# ### ✅ 8. Correlation Matrix

# %% [markdown]
# ### ✅ 9. Business Insights

# %% [markdown]
# ## Phase 4: Data Preparing For Modeling
# - ✅ 10. Groupby and Create new Features
# - ✅ 11. Outliers Handling
# - ✅ 12. Clustring

# %% [markdown]
# ### ✅ 10. Groupby and Create new Features

# %%
data = (df.groupby("Order ID").agg(
    {
        'Order Date':lambda x: x.mode().iloc[0],
        'year':lambda x: x.mode().iloc[0],
        'month':lambda x: x.mode().iloc[0],
        'day_of_week':lambda x: x.mode().iloc[0],
        'is_weekend':lambda x: x.mode().iloc[0],
        'Quarter':lambda x: x.mode().iloc[0],
        'ShippingDuration':'mean',
        'Ship Mode':lambda x: x.mode().iloc[0],
        'Segment':lambda x: x.mode().iloc[0],
        'State':lambda x: x.mode().iloc[0],
        'Region':lambda x: x.mode().iloc[0],
        'Product ID':'nunique',
        'Sales':'sum',
        
    }
)).rename(columns={
    'Product ID':'Num Products',
})
data.reset_index(inplace=True,drop=True)

# %%
data
# Out:
#      Order Date  year  month  day_of_week  is_weekend  Quarter  \
# 0    2015-07-09  2015      7            3           0        2
# 1    2015-08-07  2015      8            4           0        3
# 2    2015-03-14  2015      3            5           1        1
# 3    2015-01-28  2015      1            2           0        1
# 4    2015-05-25  2015      5            0           0        2
# ...         ...   ...    ...          ...         ...      ...
# 4035 2018-08-10  2018      8            4           0        3
# 4036 2018-03-11  2018      3            6           1        1
# 4037 2018-07-23  2018      7            0           0        2
# 4038 2018-07-09  2018      7            0           0        2
# 4039 2018-07-07  2018      7            5           1        2
#
#       ShippingDuration       Ship Mode      Segment         State   Region  \
# 0                 66.0  Standard Class     Consumer      New York     East
# 1                122.0  Standard Class    Corporate    California     West
# 2                  4.0  Standard Class  Home Office       Florida    South
# 3                 33.0  Standard Class     Consumer      New York     East
# 4                  4.0  Standard Class     Consumer      New York     East
# ...                ...             ...          ...           ...      ...
# 4035              65.0  Standard Class     Consumer      New York     East
# 4036             122.0  Standard Class    Corporate    Washington     West
# 4037               2.0    Second Class     Consumer       Indiana  Central
# 4038              62.0     First Class     Consumer  Rhode Island     East
# 4039              62.0     First Class     Consumer  Pennsylvania     East
#
#       Num Products     Sales
# 0                1   377.970
# 1                2   699.192
# 2                1    91.056
# 3                1     3.928
# 4                1    14.620
# ...            ...       ...
# 4035             1   145.764
# 4036             1    18.368
# 4037             2   171.430
# 4038             2    56.860
# 4039             6  1344.838
#
# [4040 rows x 13 columns]

# %% [markdown]
# #### 1. Sales Features

# %%
data['Avg_item_price'] = data['Sales']/data['Num Products']

# %%
data['Sales'].describe()
# Out:
# count     4040.000000
# mean       469.692740
# std       1014.899612
# min          0.556000
# 25%         36.762000
# 50%        151.456000
# 75%        504.030500
# max      23661.228000
# Name: Sales, dtype: float64

# %%
data['SalesVolume'] = pd.cut(
    data['Sales'],
    bins=[data['Sales'].quantile(0.0),data['Sales'].quantile(0.25),
          data['Sales'].quantile(0.50),data['Sales'].quantile(0.75),
          data['Sales'].quantile(.90),data['Sales'].quantile(0.966)],
    labels=[1,2,3,4,5] # 1:'Very Low', 2:'Low', 3:"Medium", 4:'High', 5:'Very High'
)

# %%
state_avg = data.groupby('State')['Sales'].transform('mean')
data['state_avg_sales'] = round(state_avg,2)

# %%
data['expanding_mean'] = data['Sales'].expanding().mean()

# %%
data
# Out:
#      Order Date  year  month  day_of_week  is_weekend  Quarter  \
# 0    2015-07-09  2015      7            3           0        2
# 1    2015-08-07  2015      8            4           0        3
# 2    2015-03-14  2015      3            5           1        1
# 3    2015-01-28  2015      1            2           0        1
# 4    2015-05-25  2015      5            0           0        2
# ...         ...   ...    ...          ...         ...      ...
# 4035 2018-08-10  2018      8            4           0        3
# 4036 2018-03-11  2018      3            6           1        1
# 4037 2018-07-23  2018      7            0           0        2
# 4038 2018-07-09  2018      7            0           0        2
# 4039 2018-07-07  2018      7            5           1        2
#
#       ShippingDuration       Ship Mode      Segment         State   Region  \
# 0                 66.0  Standard Class     Consumer      New York     East
# 1                122.0  Standard Class    Corporate    California     West
# 2                  4.0  Standard Class  Home Office       Florida    South
# 3                 33.0  Standard Class     Consumer      New York     East
# 4                  4.0  Standard Class     Consumer      New York     East
# ...                ...             ...          ...           ...      ...
# 4035              65.0  Standard Class     Consumer      New York     East
# 4036             122.0  Standard Class    Corporate    Washington     West
# 4037               2.0    Second Class     Consumer       Indiana  Central
# 4038              62.0     First Class     Consumer  Rhode Island     East
# 4039              62.0     First Class     Consumer  Pennsylvania     East
#
#       Num Products     Sales  Avg_item_price SalesVolume  state_avg_sales  \
# 0                1   377.970      377.970000           3           593.90
# 1                2   699.192      349.596000           4           453.01
# 2                1    91.056       91.056000           2           483.66
# 3                1     3.928        3.928000           1           593.90
# 4                1    14.620       14.620000           1           593.90
# ...            ...       ...             ...         ...              ...
# 4035             1   145.764      145.764000           2           593.90
# 4036             1    18.368       18.368000           1           570.92
# 4037             2   171.430       85.715000           3           738.01
# 4038             2    56.860       28.430000           2          1033.31
# 4039             6  1344.838      224.139667           5           407.33
#
#       expanding_mean
# 0         377.970000
# 1         538.581000
# 2         389.406000
# 3         293.036500
# 4         237.353200
# ...              ...
# 4035      469.763918
# 4036      469.652103
# 4037      469.578249
# 4038      469.476066
# 4039      469.692740
#
# [4040 rows x 17 columns]

# %% [markdown]
# #### 2. Lag Features (MOST IMPORTANT)

# %%
data = data.sort_values('Order Date')

data['sales_lag_1'] = data['Sales'].shift(1)
data['sales_lag_7'] = data['Sales'].shift(7)
data['sales_lag_30'] = data['Sales'].shift(30)

# %% [markdown]
# #### 3. Rolling Statistics

# %%
data['rolling_mean_7'] = data['Sales'].shift(1).rolling(7).mean()
data['rolling_mean_30'] = data['Sales'].shift(1).rolling(30).mean()
data['rolling_std_30'] = data['Sales'].shift(1).rolling(30).std()

# %% [markdown]
# #### 4. Time Based

# %%
data['is_month_start'] = data['Order Date'].dt.is_month_start.astype(int)
data['is_month_end'] = data['Order Date'].dt.is_month_end.astype(int)

# %% [markdown]
# ### ✅ 11. Outliers Handling

# %%
from datasist.structdata import detect_outliers
outs = detect_outliers(data,n=0,features=['Sales'])
data.iloc[outs]['Sales'].describe()
# Out:
# count      388.000000
# mean       665.257199
# std       1999.200835
# min          2.502000
# 25%         38.916000
# 50%        140.500000
# 75%        551.448000
# max      23661.228000
# Name: Sales, dtype: float64

# %%
len(detect_outliers(data,n=0,features=['Sales']))
# Out:
# 388

# %%
cleand_data = data.drop(outs,axis=0).dropna(axis=0).reset_index(drop=True)
cleand_data
# Out:
#      Order Date  year  month  day_of_week  is_weekend  Quarter  \
# 0    2015-01-12  2015      1            0           0        1
# 1    2015-01-12  2015      1            0           0        1
# 2    2015-01-12  2015      1            0           0        1
# 3    2015-01-13  2015      1            1           0        1
# 4    2015-01-13  2015      1            1           0        1
# ...         ...   ...    ...          ...         ...      ...
# 3618 2018-12-29  2018     12            5           1        4
# 3619 2018-12-30  2018     12            6           1        4
# 3620 2018-12-30  2018     12            6           1        4
# 3621 2018-12-30  2018     12            6           1        4
# 3622 2018-12-30  2018     12            6           1        4
#
#       ShippingDuration       Ship Mode      Segment           State   Region  \
# 0                 59.0     First Class     Consumer   Massachusetts     East
# 1                120.0  Standard Class     Consumer      California     West
# 2                 59.0    Second Class    Corporate           Texas  Central
# 3                  5.0  Standard Class     Consumer            Ohio     East
# 4                  3.0    Second Class     Consumer  South Carolina    South
# ...                ...             ...          ...             ...      ...
# 3618             123.0  Standard Class    Corporate      California     West
# 3619             122.0  Standard Class  Home Office         Indiana  Central
# 3620              61.0  Standard Class    Corporate      California     West
# 3621              61.0  Standard Class     Consumer        New York     East
# 3622              61.0  Standard Class     Consumer        Colorado     West
#
#       Num Products    Sales  Avg_item_price SalesVolume  state_avg_sales  \
# 0                3  327.560      109.186667           3           498.48
# 1                1   58.200       58.200000           2           453.01
# 2                1  674.058      674.058000           4           353.45
# 3                2   40.846       20.423000           2           306.67
# 4                1  545.940      545.940000           4           430.42
# ...            ...      ...             ...         ...              ...
# 3618             1  101.120      101.120000           2           453.01
# 3619             1  209.300      209.300000           3           738.01
# 3620             2   34.624       17.312000           1           453.01
# 3621             3  466.842      155.614000           3           593.90
# 3622             1    3.024        3.024000           1           426.33
#
#       expanding_mean  sales_lag_1  sales_lag_7  sales_lag_30  rolling_mean_7  \
# 0         461.575629     2854.480       65.800       457.568     1066.742286
# 1         450.771370      327.560       76.120       513.861     1104.136571
# 2         465.919658       58.200     2027.144       574.194     1101.576571
# 3         411.180453      674.058      733.560       651.588      908.278571
# 4         355.857495     1679.749     2854.480       204.080      988.879000
# ...              ...          ...          ...           ...             ...
# 3618      472.391534        6.030      122.530       141.000      523.254857
# 3619      467.220751      101.120      725.840       191.984      520.196286
# 3620      464.988164      209.300      695.944        31.800      446.404857
# 3621      473.892719       34.624       88.060       819.280      351.930571
# 3622      468.514908      466.842      209.700       424.172      406.042286
#
#       rolling_mean_30  rolling_std_30  is_month_start  is_month_end
# 0          600.383500      887.224990               0             0
# 1          596.049900      888.263519               0             0
# 2          580.861200      893.597088               0             0
# 3          584.190000      893.757386               0             0
# 4          658.735967      917.901855               0             0
# ...               ...             ...             ...           ...
# 3618       272.097393      382.586677               0             0
# 3619       270.768060      383.126796               0             0
# 3620       271.345260      383.017039               0             0
# 3621       271.439393      382.956479               0             0
# 3622       259.691460      370.783267               0             0
#
# [3623 rows x 25 columns]

# %%
data.dropna(axis=0,inplace=True)
data.reset_index(inplace=True,drop=True)

# %%
data
# Out:
#      Order Date  year  month  day_of_week  is_weekend  Quarter  \
# 0    2015-01-12  2015      1            0           0        1
# 1    2015-01-12  2015      1            0           0        1
# 2    2015-01-12  2015      1            0           0        1
# 3    2015-01-12  2015      1            0           0        1
# 4    2015-01-13  2015      1            1           0        1
# ...         ...   ...    ...          ...         ...      ...
# 3867 2018-12-29  2018     12            5           1        4
# 3868 2018-12-30  2018     12            6           1        4
# 3869 2018-12-30  2018     12            6           1        4
# 3870 2018-12-30  2018     12            6           1        4
# 3871 2018-12-30  2018     12            6           1        4
#
#       ShippingDuration       Ship Mode      Segment          State   Region  \
# 0                 59.0    Second Class     Consumer           Ohio     East
# 1                 59.0     First Class     Consumer  Massachusetts     East
# 2                120.0  Standard Class     Consumer     California     West
# 3                 59.0    Second Class    Corporate          Texas  Central
# 4                  5.0  Standard Class     Consumer           Ohio     East
# ...                ...             ...          ...            ...      ...
# 3867             123.0  Standard Class    Corporate     California     West
# 3868             122.0  Standard Class  Home Office        Indiana  Central
# 3869              61.0  Standard Class    Corporate     California     West
# 3870              61.0  Standard Class     Consumer       New York     East
# 3871              61.0  Standard Class     Consumer       Colorado     West
#
#       Num Products     Sales  Avg_item_price SalesVolume  state_avg_sales  \
# 0                4  1614.124      403.531000           5           306.67
# 1                3   327.560      109.186667           3           498.48
# 2                1    58.200       58.200000           2           453.01
# 3                1   674.058      674.058000           4           353.45
# 4                2    40.846       20.423000           2           306.67
# ...            ...       ...             ...         ...              ...
# 3867             1   101.120      101.120000           2           453.01
# 3868             1   209.300      209.300000           3           738.01
# 3869             2    34.624       17.312000           1           453.01
# 3870             3   466.842      155.614000           3           593.90
# 3871             1     3.024        3.024000           1           426.33
#
#       expanding_mean  sales_lag_1  sales_lag_7  sales_lag_30  rolling_mean_7  \
# 0         541.585556       95.968       75.160       468.900      441.349714
# 1         461.575629     2854.480       65.800       457.568     1066.742286
# 2         450.771370      327.560       76.120       513.861     1104.136571
# 3         465.919658       58.200     2027.144       574.194     1101.576571
# 4         411.180453      674.058      733.560       651.588      908.278571
# ...              ...          ...          ...           ...             ...
# 3867      472.391534        6.030      122.530       141.000      523.254857
# 3868      467.220751      101.120      725.840       191.984      520.196286
# 3869      464.988164      209.300      695.944        31.800      446.404857
# 3870      473.892719       34.624       88.060       819.280      351.930571
# 3871      468.514908      466.842      209.700       424.172      406.042286
#
#       rolling_mean_30  rolling_std_30  is_month_start  is_month_end
# 0          467.258033      755.627982               0             0
# 1          600.383500      887.224990               0             0
# 2          596.049900      888.263519               0             0
# 3          580.861200      893.597088               0             0
# 4          584.190000      893.757386               0             0
# ...               ...             ...             ...           ...
# 3867       272.097393      382.586677               0             0
# 3868       270.768060      383.126796               0             0
# 3869       271.345260      383.017039               0             0
# 3870       271.439393      382.956479               0             0
# 3871       259.691460      370.783267               0             0
#
# [3872 rows x 25 columns]

# %% [markdown]
# ### ✅ 12. Clustring

# %%
# Machine learning models & tools
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder, LabelEncoder, StandardScaler , RobustScaler  , MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans 
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score
from sklearn.manifold import TSNE
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# %% [markdown]
# #### 1. Encode Data

# %%
cleand_data.select_dtypes(include='object').columns
# Out:
# Index(['Ship Mode', 'Segment', 'State', 'Region'], dtype='object')

# %%
for col in cleand_data.select_dtypes(include='object').columns:
    print(f"""{col} --> Nunique = {cleand_data[col].nunique()}""")
# Out:
# Ship Mode --> Nunique = 4
# Segment --> Nunique = 3
# State --> Nunique = 47
# Region --> Nunique = 4

# %%
onh = ['Ship Mode', 'Segment', 'Region']

encoder = ColumnTransformer(
    transformers=[
        (
            'OneHot Categories',
            OneHotEncoder(),
            onh
        ),
        (
            'Label Column',OrdinalEncoder(
                handle_unknown='use_encoded_value',
                unknown_value=-1
            )
            ,['State']
        )
    ],
    remainder='passthrough'
)

# %% [markdown]
# #### 2. Steps

# %%
steps = [
    ('Encoding',encoder),
    ('Scaling',StandardScaler()),
    ("Model",KMeans())
]

# %% [markdown]
# #### 3. Optimal Cluster

# %%
def Optimal_cluster(data, encoder, n_max=7):

    wcss = []
    silhouette_scores = []
    calinski_scores = []
    davies_scores = []

    cluster_range = range(2, n_max + 1)

    # preprocessing فقط
    preprocess = Pipeline([
        ('Encoding', encoder),
        ('Scaling', StandardScaler())
    ])

    X_transformed = preprocess.fit_transform(data)

    for k in cluster_range:
        kmeans = KMeans(
            n_clusters=k,
            random_state=42,
            n_init=20,
            init='k-means++'
        )

        labels = kmeans.fit_predict(X_transformed)

        # WCSS (Elbow)
        wcss.append(kmeans.inertia_)

        # Metrics
        silhouette_scores.append(silhouette_score(X_transformed, labels))
        calinski_scores.append(calinski_harabasz_score(X_transformed, labels))
        davies_scores.append(davies_bouldin_score(X_transformed, labels))

    print(f"The Optimal n_clusters by Elbow Method is: {np.argmin(wcss)+2}") # +2 because range starts from 2
    print(f"The Optimal n_clusters by Silhouette Score is: { np.argmax(silhouette_scores) + 2}")
    print(f"The Optimal n_clusters by Calinski Score is: {np.argmax(calinski_scores) + 2}")
    print(f"The Optimal n_clusters by Davies Score is: {np.argmin(davies_scores) + 2}")
   

    

    suggestions = [
        np.argmin(wcss) + 2,
        np.argmax(silhouette_scores) + 2,
        np.argmax(calinski_scores) + 2,
        np.argmin(davies_scores) + 2
    ]

    optimal_k = max(set(suggestions), key=suggestions.count)
    print(f"Consensus optimal clusters: {optimal_k}") # most frequently suggested number of clusters

    return wcss, silhouette_scores, calinski_scores, davies_scores, cluster_range

wcss,silhouette_scores,calinski_scores,davies_scores,cluster_range=Optimal_cluster(data=cleand_data.drop(['Order Date','year'],axis=1),n_max=7,encoder=encoder) # apply the function
# Out:
# The Optimal n_clusters by Elbow Method is: 7
# The Optimal n_clusters by Silhouette Score is: 6
# The Optimal n_clusters by Calinski Score is: 2
# The Optimal n_clusters by Davies Score is: 6
# Consensus optimal clusters: 6

# %%
# now let's plot all the metrics to visualize
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 10))

# Elbow Method
ax1.plot(cluster_range, wcss, 'bo-')
ax1.set_xlabel('Number of Clusters')
ax1.set_ylabel('WCSS')
ax1.set_title('Elbow Method')
ax1.grid(True)

# Silhouette Score
ax2.plot(range(2, 8), silhouette_scores, 'ro-')
ax2.set_xlabel('Number of Clusters')
ax2.set_ylabel('Silhouette Score')
ax2.set_title('Silhouette Analysis')
ax2.grid(True)

# Calinski-Harabasz Score (Higher is better)
ax3.plot(range(2,8), calinski_scores, 'go-')
ax3.set_xlabel('Number of Clusters')
ax3.set_ylabel('Calinski-Harabasz Score')
ax3.set_title('Variance Ratio (Higher is better)')
ax3.grid(True)

# Davies-Bouldin Score (Lower is better)
ax4.plot(range(2, 8), davies_scores, 'mo-')
ax4.set_xlabel('Number of Clusters')
ax4.set_ylabel('Davies-Bouldin Score')
ax4.set_title('Separation (Lower is better)')
ax4.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 4. Hyper Parameter

# %%
# let's tune hyperparameters for KMeans we can use it evvery time we want to use KMeans
def hyperparameter (data,max_iter_range = 500 , n_clusters = 2,init_algorithem="auto",encoder=encoder,scaler=StandardScaler):
    """
    Hyperparameter tuning for KMeans clustering.

    Parameters:
    ----------
    data : array-like
        Scaled dataframe or numpy array.
    max_iter_range : int, default=500
        Maximum number of iterations to try (looped in steps of 100).
    n_clusters : int, default=2
        Number of clusters for KMeans.
    init_algorithem : str or int, default="auto"
        "auto" → test all combos in init_algorithems
        int 1–4 → pick one specific init/algorithm combo
        1: (init = 'k-means++' ,algorithem = "lloyd")
        2: (init = 'random' ,algorithem = "lloyd")
        3: (init = 'k-means++' ,algorithem = 'elkan')
        4: (init = 'random' ,algorithem = 'elkan')

    scaler : MinMaxScaler()

    Returns:
    -------
    pd.DataFrame : Results of each run with evaluation metrics.
    best_model : fitted clustering model (KMeans here)
    best_row : pd.Series (the best parameters row)
    labels : ndarray
        Cluster labels predicted for dataset X
    """


    results = []

    init_algorithems = [
        ('k-means++', 'lloyd'),
        ('random', 'lloyd'),
        ('k-means++', 'elkan'),
        ('random', 'elkan'),
    ]

    if init_algorithem == "auto":
        algos_to_test = init_algorithems
    elif isinstance(init_algorithem, int) and 1 <= init_algorithem <= 4:
        algos_to_test = [init_algorithems[init_algorithem - 1]]
    else:
        raise ValueError("init_algorithem must be 'auto' or integer 1–4")

    # ---------- Preprocessing ----------
    preprocess = Pipeline([
        ('Encoding', encoder),
        ('Scaling', MinMaxScaler())
    ])

    X = preprocess.fit_transform(data)

    # ---------- Grid Search ----------
    for max_iter in range(100, max_iter_range + 1, 100):
        for init, algorithm in algos_to_test:

            model = KMeans(
                n_clusters=n_clusters,
                init=init,
                algorithm=algorithm,
                max_iter=max_iter,
                n_init=20,
                random_state=42
            )

            labels = model.fit_predict(X)

            sil = silhouette_score(X, labels)
            cal = calinski_harabasz_score(X, labels)
            dav = davies_bouldin_score(X, labels)

            results.append({
                "n_clusters": n_clusters,
                "init": init,
                "algorithm": algorithm,
                "max_iter": max_iter,
                "silhouette_score": sil,
                "calinski_harabasz_score": cal,
                "davies_bouldin_score": dav
            })

    results_df = pd.DataFrame(results)

    # ---------- Handle edge case ----------
    if (
        results_df['silhouette_score'].nunique() == 1 and
        results_df['calinski_harabasz_score'].nunique() == 1 and
        results_df['davies_bouldin_score'].nunique() == 1
    ):
        best_row = results_df.iloc[0]

    else:
        scale = scaler()

        results_df[['silhouette_norm', 'calinski_norm']] = scale.fit_transform(
            results_df[['silhouette_score', 'calinski_harabasz_score']]
        )

        results_df['davies_norm'] = 1 - scale.fit_transform(
            results_df[['davies_bouldin_score']]
        )

        results_df['final_score'] = (
            results_df['silhouette_norm'] +
            results_df['calinski_norm'] +
            results_df['davies_norm']
        )

        best_row = results_df.loc[results_df['final_score'].idxmax()]

    # ---------- Refit Best Model ----------
    best_model = KMeans(
        n_clusters=int(best_row['n_clusters']),
        init=best_row['init'],
        algorithm=best_row['algorithm'],
        max_iter=int(best_row['max_iter']),
        n_init=20,
        random_state=42
    )

    labels = best_model.fit_predict(X)

    return results_df, best_row, labels

# %%
# %%time
results, best_params, labels = hyperparameter(
    data=cleand_data.drop(['Order Date', 'year'], axis=1),
    encoder=encoder,
    n_clusters=6
)
# Out:
# CPU times: total: 36 s
# Wall time: 7.93 s

# %%
labels
# Out:
# array([0, 2, 5, ..., 4, 0, 2], shape=(3623,), dtype=int32)

# %%
cleand_data['Clusters'] = labels

# %%
cleand_data
# Out:
#      Order Date  year  month  day_of_week  is_weekend  Quarter  \
# 0    2015-01-12  2015      1            0           0        1
# 1    2015-01-12  2015      1            0           0        1
# 2    2015-01-12  2015      1            0           0        1
# 3    2015-01-13  2015      1            1           0        1
# 4    2015-01-13  2015      1            1           0        1
# ...         ...   ...    ...          ...         ...      ...
# 3618 2018-12-29  2018     12            5           1        4
# 3619 2018-12-30  2018     12            6           1        4
# 3620 2018-12-30  2018     12            6           1        4
# 3621 2018-12-30  2018     12            6           1        4
# 3622 2018-12-30  2018     12            6           1        4
#
#       ShippingDuration       Ship Mode      Segment           State   Region  \
# 0                 59.0     First Class     Consumer   Massachusetts     East
# 1                120.0  Standard Class     Consumer      California     West
# 2                 59.0    Second Class    Corporate           Texas  Central
# 3                  5.0  Standard Class     Consumer            Ohio     East
# 4                  3.0    Second Class     Consumer  South Carolina    South
# ...                ...             ...          ...             ...      ...
# 3618             123.0  Standard Class    Corporate      California     West
# 3619             122.0  Standard Class  Home Office         Indiana  Central
# 3620              61.0  Standard Class    Corporate      California     West
# 3621              61.0  Standard Class     Consumer        New York     East
# 3622              61.0  Standard Class     Consumer        Colorado     West
#
#       Num Products    Sales  Avg_item_price SalesVolume  state_avg_sales  \
# 0                3  327.560      109.186667           3           498.48
# 1                1   58.200       58.200000           2           453.01
# 2                1  674.058      674.058000           4           353.45
# 3                2   40.846       20.423000           2           306.67
# 4                1  545.940      545.940000           4           430.42
# ...            ...      ...             ...         ...              ...
# 3618             1  101.120      101.120000           2           453.01
# 3619             1  209.300      209.300000           3           738.01
# 3620             2   34.624       17.312000           1           453.01
# 3621             3  466.842      155.614000           3           593.90
# 3622             1    3.024        3.024000           1           426.33
#
#       expanding_mean  sales_lag_1  sales_lag_7  sales_lag_30  rolling_mean_7  \
# 0         461.575629     2854.480       65.800       457.568     1066.742286
# 1         450.771370      327.560       76.120       513.861     1104.136571
# 2         465.919658       58.200     2027.144       574.194     1101.576571
# 3         411.180453      674.058      733.560       651.588      908.278571
# 4         355.857495     1679.749     2854.480       204.080      988.879000
# ...              ...          ...          ...           ...             ...
# 3618      472.391534        6.030      122.530       141.000      523.254857
# 3619      467.220751      101.120      725.840       191.984      520.196286
# 3620      464.988164      209.300      695.944        31.800      446.404857
# 3621      473.892719       34.624       88.060       819.280      351.930571
# 3622      468.514908      466.842      209.700       424.172      406.042286
#
#       rolling_mean_30  rolling_std_30  is_month_start  is_month_end  Clusters
# 0          600.383500      887.224990               0             0         0
# 1          596.049900      888.263519               0             0         2
# 2          580.861200      893.597088               0             0         5
# 3          584.190000      893.757386               0             0         0
# 4          658.735967      917.901855               0             0         3
# ...               ...             ...             ...           ...       ...
# 3618       272.097393      382.586677               0             0         4
# 3619       270.768060      383.126796               0             0         1
# 3620       271.345260      383.017039               0             0         4
# 3621       271.439393      382.956479               0             0         0
# 3622       259.691460      370.783267               0             0         2
#
# [3623 rows x 26 columns]

# %% [markdown]
# ## Phase 5: Modeling

# %% [markdown]
# ### ✅ 7. Search Loop

# %%
# Machine learning models & tools
from sklearn.linear_model import Ridge, Lasso
from sklearn.ensemble import (
    RandomForestRegressor,
    GradientBoostingRegressor,
    ExtraTreesRegressor,
    AdaBoostRegressor
)

from sklearn.model_selection import cross_validate, train_test_split

# Time-Series Aware CV
from sklearn.model_selection import TimeSeriesSplit

# Model evaluation metrics
from sklearn.metrics import mean_squared_error, r2_score

from sklearn.feature_selection import SequentialFeatureSelector

# %%
x = cleand_data.drop(['Sales','year','Order Date'],axis=1)
y = cleand_data['Sales']

# %% [markdown]
# #### 1. Scalers

# %%
scalers = [
    ('NoScaler','passthrough'),
    ('StandarScaler',StandardScaler()),
    ('MinMaxScaler',MinMaxScaler()),
    ("RobustScaler",RobustScaler())
]

# %% [markdown]
# #### 2. Encoders

# %%
onh = ['Ship Mode', 'Segment', 'Region']

encoder = ColumnTransformer(
    transformers=[
        (
            'OneHot Categories',
            OneHotEncoder(),
            onh
        ),
        (
            'Label Column',OrdinalEncoder(
                handle_unknown='use_encoded_value',
                unknown_value=-1
            )
            ,['State']
        )
    ],
    remainder='passthrough'
)

# %% [markdown]
# #### 3. Models

# %%
models = [
    ('Ridge', Ridge(alpha=1.0)),
    ('Lasso', Lasso(alpha=0.01)),
    ('RandomForest', RandomForestRegressor(n_estimators=300, random_state=42)),
    ('GradientBoosting', GradientBoostingRegressor(n_estimators=300, learning_rate=0.05)),
    ('ExtraTrees', ExtraTreesRegressor(n_estimators=400, random_state=42)),
    ('AdaBoost', AdaBoostRegressor(n_estimators=200, learning_rate=0.05))
]

# %% [markdown]
# #### 4. For Loop

# %%
tscv = TimeSeriesSplit(n_splits=5)

# %%
# %%time
results = []


for model in models:
    print('_' * 60)
    print('Model:', model[0])

    steps = [
        ("Encoding",encoder),
        ("Scaling",StandardScaler()),
        ('model', model[1])
    ]

    pipeline = Pipeline(steps)

    cv_results = cross_validate(
        pipeline,
        x,
        y,
        cv=tscv,
        scoring={
            'MAE': 'neg_mean_absolute_error',
            'RMSE': 'neg_root_mean_squared_error'
        },
        return_train_score=True,
        n_jobs=-1
    )

    train_rmse = -cv_results['train_RMSE'].mean()
    test_rmse = -cv_results['test_RMSE'].mean()
    test_mae = -cv_results['test_MAE'].mean()

    print(f"Train RMSE: {train_rmse:.2f}")
    print(f"Test RMSE : {test_rmse:.2f}")
    print(f"Test MAE  : {test_mae:.2f}")
# Out:
# ____________________________________________________________
# Model: Ridge
# Train RMSE: 107.39
# Test RMSE : 104.60
# Test MAE  : 78.19
# ____________________________________________________________
# Model: Lasso
# Train RMSE: 107.39
# Test RMSE : 104.61
# Test MAE  : 78.20
# ____________________________________________________________
# Model: RandomForest
# Train RMSE: 11.16
# Test RMSE : 30.25
# Test MAE  : 11.10
# ____________________________________________________________
# Model: GradientBoosting
# Train RMSE: 14.16
# Test RMSE : 24.23
# Test MAE  : 13.58
# ____________________________________________________________
# Model: ExtraTrees
# Train RMSE: 0.00
# Test RMSE : 21.15
# Test MAE  : 6.52
# ____________________________________________________________
# Model: AdaBoost
# Train RMSE: 85.69
# Test RMSE : 87.59
# Test MAE  : 57.17
# CPU times: total: 531 ms
# Wall time: 36.3 s

# %% [markdown]
# ### ✅ 14. Model Tuning
# **We have 2 Options from models Option 1: `ExtraTrees`, But need some control(Fix OverFitting problem)**
#                               **Option 2: `GradiantBoosting`, it's Balanced more than ExtraTrees**

# %% [markdown]
# #### 1. ExtraTrees

# %%
from sklearn.model_selection import GridSearchCV

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, 
                                                    test_size=0.10, 
                                                    random_state=42)

# %%
steps = [
    ("Encoding",encoder),
    ("Scaling",StandardScaler()),
    ('EX', ExtraTreesRegressor(random_state=42))
]

ET = Pipeline(steps)

# %%
ET
# Out:
# Pipeline(steps=[('Encoding',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('OneHot Categories',
#                                                   OneHotEncoder(),
#                                                   ['Ship Mode', 'Segment',
#                                                    'Region']),
#                                                  ('Label Column',
#                                                   OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                  unknown_value=-1),
#                                                   ['State'])])),
#                 ('Scaling', StandardScaler()),
#                 ('EX', ExtraTreesRegressor(random_state=42))])

# %%
param_grid = {
    "EX__n_estimators": [200, 300,400,500,600],
    "EX__max_depth": [10, 15, 20, None],
    "EX__min_samples_split": [10, 20, 50],
    "EX__min_samples_leaf": [5, 10, 20],
    "EX__max_features": [0.3, 0.5,0.7, "sqrt"]
}

# %%
grid_search = GridSearchCV(
    estimator=ET,
    param_grid=param_grid,
    scoring={
        'MAE': 'neg_mean_absolute_error',
        'RMSE': 'neg_root_mean_squared_error'
    },
    refit='RMSE', 
    cv=8,
    n_jobs=-1,
    verbose=2
)

# %%
grid_search
# Out:
# GridSearchCV(cv=8,
#              estimator=Pipeline(steps=[('Encoding',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('OneHot '
#                                                                          'Categories',
#                                                                          OneHotEncoder(),
#                                                                          ['Ship '
#                                                                           'Mode',
#                                                                           'Segment',
#                                                                           'Region']),
#                                                                         ('Label '
#                                                                          'Column',
#                                                                          OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                         unknown_value=-1),
#                                                                          ['State'])])),
#                                        ('Scaling', StandardScaler()),
#                                        ('EX',
#                                         ExtraTreesRegressor(random_state=42))]),
#              n_jobs=-1,
#              param_grid={'EX__max_depth': [10, 15, 20, None],
#                          'EX__max_features': [0.3, 0.5, 0.7, 'sqrt'],
#                          'EX__min_samples_leaf': [5, 10, 20],
#                          'EX__min_samples_split': [10, 20, 50],
#                          'EX__n_estimators': [200, 300, 400, 500, 600]},
#              refit='RMSE',
#              scoring={'MAE': 'neg_mean_absolute_error',
#                       'RMSE': 'neg_root_mean_squared_error'},
#              verbose=2)

# %%
# %%time
grid_search.fit(x_train,y_train)
# Out:
# Fitting 8 folds for each of 720 candidates, totalling 5760 fits
# CPU times: total: 39.9 s
# Wall time: 23min 11s
# C:\Users\ahmed\anaconda3\envs\ds\Lib\site-packages\sklearn\compose\_column_transformer.py:1667: FutureWarning:
#
#
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
# GridSearchCV(cv=8,
#              estimator=Pipeline(steps=[('Encoding',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('OneHot '
#                                                                          'Categories',
#                                                                          OneHotEncoder(),
#                                                                          ['Ship '
#                                                                           'Mode',
#                                                                           'Segment',
#                                                                           'Region']),
#                                                                         ('Label '
#                                                                          'Column',
#                                                                          OrdinalEncoder(handle_unknown='use_encoded_value',
#                                                                                         unknown_value=-1),
#                                                                          ['State'])])),
#                                        ('Scaling', StandardScaler()),
#                                        ('EX',
#                                         ExtraTreesRegressor(random_state=42))]),
#              n_jobs=-1,
#              param_grid={'EX__max_depth': [10, 15, 20, None],
#                          'EX__max_features': [0.3, 0.5, 0.7, 'sqrt'],
#                          'EX__min_samples_leaf': [5, 10, 20],
#                          'EX__min_samples_split': [10, 20, 50],
#                          'EX__n_estimators': [200, 300, 400, 500, 600]},
#              refit='RMSE',
#              scoring={'MAE': 'neg_mean_absolute_error',
#                       'RMSE': 'neg_root_mean_squared_error'},
#              verbose=2)

# %%
cv_results = grid_search.cv_results_

test_rmse  = -cv_results['mean_test_RMSE'].mean()
test_mae   = -cv_results['mean_test_MAE'].mean()

print(f"Test RMSE : {test_rmse:.2f}")
print(f"Test MAE  : {test_mae:.2f}")
# Out:
# Test RMSE : 79.28
# Test MAE  : 47.43

# %%
-grid_search.best_score_
# Out:
# np.float64(31.153359040162368)

# %%
grid_search.best_params_
# Out:
# {'EX__max_depth': None,
#  'EX__max_features': 0.7,
#  'EX__min_samples_leaf': 5,
#  'EX__min_samples_split': 10,
#  'EX__n_estimators': 600}

# %%
y_predict = grid_search.best_estimator_.predict(x_test)

print("ExtraTrees:")
print("MSE:", mean_squared_error(y_test,y_predict))
print("R2:", r2_score(y_test, y_predict))
print("-"*40)
# Out:
# ExtraTrees:
# MSE: 925.7610019691906
# R2: 0.9899503627124283
# ----------------------------------------

# %%
plt.figure(figsize=(15,8))

plt.plot(y_test.values[:50], label="Actual sales", marker='o')  

# Plot predicted values
plt.plot(y_predict[:50], label="ExtraTrees Predicted Sales", marker='x')  
 

plt.title("Actual vs Predicted (50 Samples)", fontsize=14)
plt.xlabel("Sample Index")
plt.ylabel("Sales")
plt.legend()
plt.show()

# %%
ExtraTrees: 15
MSE: 2555.273512733075
R2: 0.9717043319268046

ExtraTrees: 10
MSE: 2310.789660976129
R2: 0.9749151261596849

ExtraTrees: 125
MSE: 2463.932734242126
R2: 0.9729631163558613
