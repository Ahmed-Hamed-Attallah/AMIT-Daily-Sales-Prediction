# %% [markdown]
# ## Import Libs

# %%
# Data manipulation & analysis
import pandas as pd
import numpy as np

# Data visualization
import matplotlib.pyplot as plt
import seaborn as sns
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# %% [markdown]
# ## Phase 1: Data Preparation & Cleaning
# - ✅ 1. Load the Data
# - ✅ 2. Clean the Data
# - ✅ 3. Feature Engineering

# %% [markdown]
# ### ✅ 1. Load the Data

# %%
df = pd.read_csv("../data/sales dataset.csv")

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3       4  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4       5  US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# 0      42420.0  South  FUR-BO-10001798        Furniture    Bookcases
# 1      42420.0  South  FUR-CH-10000454        Furniture       Chairs
# 2      90036.0   West  OFF-LA-10000240  Office Supplies       Labels
# 3      33311.0  South  FUR-TA-10000577        Furniture       Tables
# 4      33311.0  South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales
# 0                  Bush Somerset Collection Bookcase  261.9600
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4                     Eldon Fold 'N Roll Cart System   22.3680

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
#  17  Sales          9800 non-null   float64
# dtypes: float64(2), int64(1), object(15)
# memory usage: 1.3+ MB

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### ✅ 2. Clean the Data

# %%
# Drop null values
df.dropna(axis=0,inplace=True)
df.drop("Row ID",axis=1,inplace=True)

# %%
df
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1     CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2     CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3     US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4     US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# ...              ...         ...         ...             ...         ...
# 9795  CA-2017-125920  21/05/2017  28/05/2017  Standard Class    SH-19975
# 9796  CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
#
#          Customer Name    Segment        Country             City       State  \
# 0          Claire Gute   Consumer  United States        Henderson    Kentucky
# 1          Claire Gute   Consumer  United States        Henderson    Kentucky
# 2      Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3       Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4       Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# ...                ...        ...            ...              ...         ...
# 9795     Sally Hughsby  Corporate  United States          Chicago    Illinois
# 9796  Cindy Schnelling  Corporate  United States           Toledo        Ohio
# 9797  Cindy Schnelling  Corporate  United States           Toledo        Ohio
# 9798  Cindy Schnelling  Corporate  United States           Toledo        Ohio
# 9799  Cindy Schnelling  Corporate  United States           Toledo        Ohio
#
#       Postal Code   Region       Product ID         Category Sub-Category  \
# 0         42420.0    South  FUR-BO-10001798        Furniture    Bookcases
# 1         42420.0    South  FUR-CH-10000454        Furniture       Chairs
# 2         90036.0     West  OFF-LA-10000240  Office Supplies       Labels
# 3         33311.0    South  FUR-TA-10000577        Furniture       Tables
# 4         33311.0    South  OFF-ST-10000760  Office Supplies      Storage
# ...           ...      ...              ...              ...          ...
# 9795      60610.0  Central  OFF-BI-10003429  Office Supplies      Binders
# 9796      43615.0     East  OFF-AR-10001374  Office Supplies          Art
# 9797      43615.0     East  TEC-PH-10004977       Technology       Phones
# 9798      43615.0     East  TEC-PH-10000912       Technology       Phones
# 9799      43615.0     East  TEC-AC-10000487       Technology  Accessories
#
#                                            Product Name     Sales
# 0                     Bush Somerset Collection Bookcase  261.9600
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4                        Eldon Fold 'N Roll Cart System   22.3680
# ...                                                 ...       ...
# 9795  Cardinal HOLDit! Binder Insert Strips,Extra St...    3.7980
# 9796           BIC Brite Liner Highlighters, Chisel Tip   10.3680
# 9797                                        GE 30524EE4  235.1880
# 9798           Anker 24W Portable Micro USB Car Charger   26.3760
# 9799                SanDisk Cruzer 4 GB USB Flash Drive   10.3840
#
# [9789 rows x 17 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.drop_duplicates(inplace=True)
df.reset_index(inplace=True,drop=True)

# %%
df
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0     CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 1     CA-2017-152156  08/11/2017  11/11/2017    Second Class    CG-12520
# 2     CA-2017-138688  12/06/2017  16/06/2017    Second Class    DV-13045
# 3     US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# 4     US-2016-108966  11/10/2016  18/10/2016  Standard Class    SO-20335
# ...              ...         ...         ...             ...         ...
# 9783  CA-2017-125920  21/05/2017  28/05/2017  Standard Class    SH-19975
# 9784  CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9785  CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9786  CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
# 9787  CA-2016-128608  12/01/2016  17/01/2016  Standard Class    CS-12490
#
#          Customer Name    Segment        Country             City       State  \
# 0          Claire Gute   Consumer  United States        Henderson    Kentucky
# 1          Claire Gute   Consumer  United States        Henderson    Kentucky
# 2      Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3       Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4       Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# ...                ...        ...            ...              ...         ...
# 9783     Sally Hughsby  Corporate  United States          Chicago    Illinois
# 9784  Cindy Schnelling  Corporate  United States           Toledo        Ohio
# 9785  Cindy Schnelling  Corporate  United States           Toledo        Ohio
# 9786  Cindy Schnelling  Corporate  United States           Toledo        Ohio
# 9787  Cindy Schnelling  Corporate  United States           Toledo        Ohio
#
#       Postal Code   Region       Product ID         Category Sub-Category  \
# 0         42420.0    South  FUR-BO-10001798        Furniture    Bookcases
# 1         42420.0    South  FUR-CH-10000454        Furniture       Chairs
# 2         90036.0     West  OFF-LA-10000240  Office Supplies       Labels
# 3         33311.0    South  FUR-TA-10000577        Furniture       Tables
# 4         33311.0    South  OFF-ST-10000760  Office Supplies      Storage
# ...           ...      ...              ...              ...          ...
# 9783      60610.0  Central  OFF-BI-10003429  Office Supplies      Binders
# 9784      43615.0     East  OFF-AR-10001374  Office Supplies          Art
# 9785      43615.0     East  TEC-PH-10004977       Technology       Phones
# 9786      43615.0     East  TEC-PH-10000912       Technology       Phones
# 9787      43615.0     East  TEC-AC-10000487       Technology  Accessories
#
#                                            Product Name     Sales
# 0                     Bush Somerset Collection Bookcase  261.9600
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# 2     Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3         Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4                        Eldon Fold 'N Roll Cart System   22.3680
# ...                                                 ...       ...
# 9783  Cardinal HOLDit! Binder Insert Strips,Extra St...    3.7980
# 9784           BIC Brite Liner Highlighters, Chisel Tip   10.3680
# 9785                                        GE 30524EE4  235.1880
# 9786           Anker 24W Portable Micro USB Car Charger   26.3760
# 9787                SanDisk Cruzer 4 GB USB Flash Drive   10.3840
#
# [9788 rows x 17 columns]

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'],format="mixed")
df['Ship Date'] = pd.to_datetime(df['Ship Date'],format="mixed")

# %% [markdown]
# ### ✅ 3. Feature Engineering

# %% [markdown]
# #### 1. Shipping Duration

# %%
df["ShippingDuration"] =  (df['Ship Date'] - df['Order Date']).dt.days

# %%
df.head()
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 1  CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 2  CA-2017-138688 2017-12-06 2017-06-16    Second Class    DV-13045
# 3  US-2016-108966 2016-11-10 2016-10-18  Standard Class    SO-20335
# 4  US-2016-108966 2016-11-10 2016-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# 0      42420.0  South  FUR-BO-10001798        Furniture    Bookcases
# 1      42420.0  South  FUR-CH-10000454        Furniture       Chairs
# 2      90036.0   West  OFF-LA-10000240  Office Supplies       Labels
# 3      33311.0  South  FUR-TA-10000577        Furniture       Tables
# 4      33311.0  South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  \
# 0                  Bush Somerset Collection Bookcase  261.9600
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775
# 4                     Eldon Fold 'N Roll Cart System   22.3680
#
#    ShippingDuration
# 0                92
# 1                92
# 2              -173
# 3               -23
# 4               -23

# %%
idx = df[df['Order Date']>df['Ship Date']].index.tolist()
df.drop(idx,axis=0,inplace=True)

# %%
df
# Out:
#             Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 1     CA-2017-152156 2017-08-11 2017-11-11    Second Class    CG-12520
# 12    CA-2018-114412 2018-04-15 2018-04-20  Standard Class    AA-10480
# 13    CA-2017-161389 2017-05-12 2017-10-12  Standard Class    IM-15070
# 14    US-2016-118983 2016-11-22 2016-11-26  Standard Class    HP-14815
# ...              ...        ...        ...             ...         ...
# 9779  CA-2015-127166 2015-05-21 2015-05-23    Second Class    KH-16360
# 9780  CA-2015-127166 2015-05-21 2015-05-23    Second Class    KH-16360
# 9781  CA-2015-127166 2015-05-21 2015-05-23    Second Class    KH-16360
# 9782  CA-2015-127166 2015-05-21 2015-05-23    Second Class    KH-16360
# 9783  CA-2017-125920 2017-05-21 2017-05-28  Standard Class    SH-19975
#
#          Customer Name      Segment        Country        City  \
# 0          Claire Gute     Consumer  United States   Henderson
# 1          Claire Gute     Consumer  United States   Henderson
# 12        Andrew Allen     Consumer  United States     Concord
# 13        Irene Maddox     Consumer  United States     Seattle
# 14       Harold Pawlan  Home Office  United States  Fort Worth
# ...                ...          ...            ...         ...
# 9779  Katherine Hughes     Consumer  United States     Houston
# 9780  Katherine Hughes     Consumer  United States     Houston
# 9781  Katherine Hughes     Consumer  United States     Houston
# 9782  Katherine Hughes     Consumer  United States     Houston
# 9783     Sally Hughsby    Corporate  United States     Chicago
#
#                State  Postal Code   Region       Product ID         Category  \
# 0           Kentucky      42420.0    South  FUR-BO-10001798        Furniture
# 1           Kentucky      42420.0    South  FUR-CH-10000454        Furniture
# 12    North Carolina      28027.0    South  OFF-PA-10002365  Office Supplies
# 13        Washington      98103.0     West  OFF-BI-10003656  Office Supplies
# 14             Texas      76106.0  Central  OFF-AP-10002311  Office Supplies
# ...              ...          ...      ...              ...              ...
# 9779           Texas      77070.0  Central  OFF-EN-10003134  Office Supplies
# 9780           Texas      77070.0  Central  FUR-CH-10003396        Furniture
# 9781           Texas      77070.0  Central  OFF-PA-10001560  Office Supplies
# 9782           Texas      77070.0  Central  OFF-BI-10000977  Office Supplies
# 9783        Illinois      60610.0  Central  OFF-BI-10003429  Office Supplies
#
#      Sub-Category                                       Product Name    Sales  \
# 0       Bookcases                  Bush Somerset Collection Bookcase  261.960
# 1          Chairs  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.940
# 12          Paper                                         Xerox 1967   15.552
# 13        Binders        Fellowes PB200 Plastic Comb Binding Machine  407.976
# 14     Appliances  Holmes Replacement Filter for HEPA Air Cleaner...   68.810
# ...           ...                                                ...      ...
# 9779    Envelopes                                    Staple envelope   56.064
# 9780       Chairs                          Global Deluxe Steno Chair  107.772
# 9781        Paper        Adams Telephone Message Books, 5 1/4” x 11”    4.832
# 9782      Binders                 Ibico Plastic Spiral Binding Combs   18.240
# 9783      Binders  Cardinal HOLDit! Binder Insert Strips,Extra St...    3.798
#
#       ShippingDuration
# 0                   92
# 1                   92
# 12                   5
# 13                 153
# 14                   4
# ...                ...
# 9779                 2
# 9780                 2
# 9781                 2
# 9782                 2
# 9783                 7
#
# [8104 rows x 18 columns]

# %% [markdown]
# #### 2. Aggregation For Forecasting

# %%
#Daily Sales
ds = (
    df.groupby("Order Date").agg(
        {
            'Sales': 'sum',
            'Order ID':'nunique',
            "ShippingDuration":'mean'
        }
    ).rename(columns={
          'Sales': 'daily_sales',
          'Order ID': 'num_orders',
        "ShippingDuration":'AVG_ShippingDuration'
      })
      .reset_index()
)
ds.head()
# Out:
#   Order Date  daily_sales  num_orders  AVG_ShippingDuration
# 0 2015-01-02      468.900           1             59.000000
# 1 2015-01-03     2203.151           5            135.300000
# 2 2015-01-04      119.888           2            151.000000
# 3 2015-01-06     5188.520           4            151.000000
# 4 2015-01-07      601.024           2            130.333333

# %% [markdown]
# #### 3. Time-Based Features

# %%
ds['year'] = ds['Order Date'].dt.year
ds['month'] = ds['Order Date'].dt.month
ds['day_of_week'] = ds['Order Date'].dt.dayofweek
ds['is_weekend'] = (ds['day_of_week']>= 5).astype(int)
ds['Quarter'] = round(ds["month"]/3)

# %%
ds.head()
# Out:
#   Order Date  daily_sales  num_orders  AVG_ShippingDuration  year  month  \
# 0 2015-01-02      468.900           1             59.000000  2015      1
# 1 2015-01-03     2203.151           5            135.300000  2015      1
# 2 2015-01-04      119.888           2            151.000000  2015      1
# 3 2015-01-06     5188.520           4            151.000000  2015      1
# 4 2015-01-07      601.024           2            130.333333  2015      1
#
#    day_of_week  is_weekend  Quarter
# 0            4           0      0.0
# 1            5           1      0.0
# 2            6           1      0.0
# 3            1           0      0.0
# 4            2           0      0.0

# %%
ds.is_weekend.value_counts()
# Out:
# is_weekend
# 0    744
# 1    327
# Name: count, dtype: int64

# %%
ds['AVG_ShippingDuration'] = ds['AVG_ShippingDuration'].apply(lambda x: round(x))
ds['Quarter'] = ds['Quarter'].apply(lambda x: round(x))
ds.head()
# Out:
#   Order Date  daily_sales  num_orders  AVG_ShippingDuration  year  month  \
# 0 2015-01-02      468.900           1                    59  2015      1
# 1 2015-01-03     2203.151           5                   135  2015      1
# 2 2015-01-04      119.888           2                   151  2015      1
# 3 2015-01-06     5188.520           4                   151  2015      1
# 4 2015-01-07      601.024           2                   130  2015      1
#
#    day_of_week  is_weekend  Quarter
# 0            4           0        0
# 1            5           1        0
# 2            6           1        0
# 3            1           0        0
# 4            2           0        0

# %% [markdown]
# #### 4. Lag Features (MOST IMPORTANT)

# %%
ds = ds.sort_values('Order Date')

ds['sales_lag_1'] = ds['daily_sales'].shift(1)
ds['sales_lag_7'] = ds['daily_sales'].shift(7)
ds['sales_lag_30'] = ds['daily_sales'].shift(30)

# %% [markdown]
# #### 5. Rolling Statistics

# %%
ds['rolling_mean_7'] = ds['daily_sales'].shift(1).rolling(7).mean()
ds['rolling_mean_30'] = ds['daily_sales'].shift(1).rolling(30).mean()
ds['rolling_std_30'] = ds['daily_sales'].shift(1).rolling(30).std()

# %%
ds
# Out:
#      Order Date  daily_sales  num_orders  AVG_ShippingDuration  year  month  \
# 0    2015-01-02     468.9000           1                    59  2015      1
# 1    2015-01-03    2203.1510           5                   135  2015      1
# 2    2015-01-04     119.8880           2                   151  2015      1
# 3    2015-01-06    5188.5200           4                   151  2015      1
# 4    2015-01-07     601.0240           2                   130  2015      1
# ...         ...          ...         ...                   ...   ...    ...
# 1066 2018-12-26     814.5940           4                     4  2018     12
# 1067 2018-12-27     177.6360           1                     0  2018     12
# 1068 2018-12-28    1657.3508          10                    32  2018     12
# 1069 2018-12-29    2915.5340           6                    31  2018     12
# 1070 2018-12-30     713.7900           4                    70  2018     12
#
#       day_of_week  is_weekend  Quarter  sales_lag_1  sales_lag_7  \
# 0               4           0        0          NaN          NaN
# 1               5           1        0     468.9000          NaN
# 2               6           1        0    2203.1510          NaN
# 3               1           0        0     119.8880          NaN
# 4               2           0        0    5188.5200          NaN
# ...           ...         ...      ...          ...          ...
# 1066            2           0        4    2698.9270     1895.926
# 1067            3           0        4     814.5940      377.736
# 1068            4           0        4     177.6360     2140.940
# 1069            5           1        4    1657.3508     7442.021
# 1070            6           1        4    2915.5340     1926.776
#
#       sales_lag_30  rolling_mean_7  rolling_mean_30  rolling_std_30
# 0              NaN             NaN              NaN             NaN
# 1              NaN             NaN              NaN             NaN
# 2              NaN             NaN              NaN             NaN
# 3              NaN             NaN              NaN             NaN
# 4              NaN             NaN              NaN             NaN
# ...            ...             ...              ...             ...
# 1066      559.2000     3245.054286      2760.441260     2845.781456
# 1067     4755.2340     3090.578286      2768.954393     2839.344114
# 1068    13408.7928     3061.992571      2616.367793     2851.893014
# 1069     1469.7560     2992.908400      2224.653060     1997.460304
# 1070     7397.2720     2346.267400      2272.845660     1996.059510
#
# [1071 rows x 15 columns]

# %%
model_df = ds.dropna().reset_index(drop=True)

model_df
# Out:
#      Order Date  daily_sales  num_orders  AVG_ShippingDuration  year  month  \
# 0    2015-02-09    3254.1500           7                   103  2015      2
# 1    2015-02-10     598.1440           1                    89  2015      2
# 2    2015-02-11    2126.3700           6                   128  2015      2
# 3    2015-02-12    1771.8080           6                   126  2015      2
# 4    2015-02-14     576.7260           2                     4  2015      2
# ...         ...          ...         ...                   ...   ...    ...
# 1036 2018-12-26     814.5940           4                     4  2018     12
# 1037 2018-12-27     177.6360           1                     0  2018     12
# 1038 2018-12-28    1657.3508          10                    32  2018     12
# 1039 2018-12-29    2915.5340           6                    31  2018     12
# 1040 2018-12-30     713.7900           4                    70  2018     12
#
#       day_of_week  is_weekend  Quarter  sales_lag_1  sales_lag_7  \
# 0               0           0        1     886.2800      211.646
# 1               1           0        1    3254.1500       47.760
# 2               2           0        1     598.1440     1458.558
# 3               3           0        1    2126.3700      506.120
# 4               5           1        1    1771.8080      738.598
# ...           ...         ...      ...          ...          ...
# 1036            2           0        4    2698.9270     1895.926
# 1037            3           0        4     814.5940      377.736
# 1038            4           0        4     177.6360     2140.940
# 1039            5           1        4    1657.3508     7442.021
# 1040            6           1        4    2915.5340     1926.776
#
#       sales_lag_30  rolling_mean_7  rolling_mean_30  rolling_std_30
# 0         468.9000      561.217429      1091.892533     1612.019946
# 1        2203.1510      995.860857      1184.734200     1654.547456
# 2         119.8880     1074.487143      1131.233967     1646.410288
# 3        5188.5200     1169.888857      1198.116700     1644.663411
# 4         601.0240     1350.701429      1084.226300     1467.572319
# ...            ...             ...              ...             ...
# 1036      559.2000     3245.054286      2760.441260     2845.781456
# 1037     4755.2340     3090.578286      2768.954393     2839.344114
# 1038    13408.7928     3061.992571      2616.367793     2851.893014
# 1039     1469.7560     2992.908400      2224.653060     1997.460304
# 1040     7397.2720     2346.267400      2272.845660     1996.059510
#
# [1041 rows x 15 columns]

# %%
model_df.to_csv("../data/model_df.csv",index=False)

# %% [markdown]
# **✅ Phase 1 Complete: Data cleaning and feature engineering are now finished. The dataset is fully prepared and ready for analysis.**
# **Next Step — Phase 2: Let’s move on to the analysis and insight generation stage.**
#
# ## Phase 2: Exploratory Data Analysis (EDA) & Visualization
# - ✅ 4. General Overview
# - ✅ 5. IQR outlier detection
# - ✅ 6. ADF test

# %% [markdown]
# ### ✅ 4. General Overview

# %% [markdown]
# #### 1. Descriptive Stat

# %%
ds.describe().T
# Out:
#                        count                           mean  \
# Order Date              1071  2017-01-14 01:38:09.075630080
# daily_sales           1071.0                    1771.763462
# num_orders            1071.0                       3.772176
# AVG_ShippingDuration  1071.0                      39.763772
# year                  1071.0                    2016.551821
# month                 1071.0                       6.355742
# day_of_week           1071.0                       2.943978
# is_weekend            1071.0                       0.305322
# Quarter               1071.0                       2.116713
# sales_lag_1           1070.0                    1772.752223
# sales_lag_7           1064.0                    1769.123856
# sales_lag_30          1041.0                    1763.743305
# rolling_mean_7        1064.0                    1773.099397
# rolling_mean_30       1041.0                    1771.708308
# rolling_std_30        1041.0                    2146.075754
#
#                                       min                  25%  \
# Order Date            2015-01-02 00:00:00  2016-01-21 00:00:00
# daily_sales                         1.744              310.784
# num_orders                            1.0                  2.0
# AVG_ShippingDuration                  0.0                  4.0
# year                               2015.0               2016.0
# month                                 1.0                  3.0
# day_of_week                           0.0                  1.0
# is_weekend                            0.0                  0.0
# Quarter                               0.0                  1.0
# sales_lag_1                         1.744              310.736
# sales_lag_7                         1.744              309.996
# sales_lag_30                        1.744              301.742
# rolling_mean_7                  29.847429          1019.842857
# rolling_mean_30                   518.594            1362.5351
# rolling_std_30                 767.059449          1445.004835
#
#                                       50%                  75%  \
# Order Date            2017-02-08 00:00:00  2018-01-21 12:00:00
# daily_sales                       944.429            2353.2855
# num_orders                            3.0                  5.0
# AVG_ShippingDuration                  5.0                 89.5
# year                               2017.0               2018.0
# month                                 6.0                  9.0
# day_of_week                           3.0                  5.0
# is_weekend                            0.0                  1.0
# Quarter                               2.0                  3.0
# sales_lag_1                      944.6965           2354.17475
# sales_lag_7                      944.3575             2325.269
# sales_lag_30                      942.108             2316.523
# rolling_mean_7                1581.045786          2340.976375
# rolling_mean_30               1725.570567          2176.239267
# rolling_std_30                2030.108037          2670.244227
#
#                                       max          std
# Order Date            2018-12-30 00:00:00          NaN
# daily_sales                     28106.716  2339.979004
# num_orders                           19.0     2.844639
# AVG_ShippingDuration                214.0    53.341706
# year                               2018.0     1.122778
# month                                12.0     3.354097
# day_of_week                           6.0     2.075365
# is_weekend                            1.0     0.460759
# Quarter                               4.0     1.180215
# sales_lag_1                     28106.716  2340.849372
# sales_lag_7                     28106.716  2342.321713
# sales_lag_30                    28106.716  2354.653961
# rolling_mean_7                5674.129143  1008.872208
# rolling_mean_30               3162.062273   552.094835
# rolling_std_30                5168.369719   891.449772

# %% [markdown]
# #### 2. Balance check

# %%
ds[['year']].value_counts()
# Out:
# year
# 2018    285
# 2017    278
# 2015    257
# 2016    251
# Name: count, dtype: int64

# %%
ds['month'].value_counts()
# Out:
# month
# 3     102
# 5     102
# 7      94
# 4      94
# 6      93
# 8      92
# 9      88
# 1      86
# 10     84
# 2      81
# 12     78
# 11     77
# Name: count, dtype: int64

# %%
ds['Quarter'].value_counts()
# Out:
# Quarter
# 2    289
# 1    277
# 3    264
# 4    155
# 0     86
# Name: count, dtype: int64

# %%
ds['is_weekend'].value_counts()
# Out:
# is_weekend
# 0    744
# 1    327
# Name: count, dtype: int64

# %% [markdown]
# #### 3. Trends Analysis

# %%
fig = go.Figure()

fig.add_trace(
    go.Scatter(
        y = ds['daily_sales'],
        x = ds['Order Date'],
        mode='lines',
        name='Daily Sales'
    )
)

fig.update_layout(
    title='Daily Sales Trend by Order Date',
    xaxis_title='Order Date',
    yaxis_title='Sales',
    hovermode='x unified'
)

fig.show()

# %% [markdown]
# ### ✅ 5. IQR outlier detection

# %%
Q1 = ds['daily_sales'].quantile(0.25)
Q3 = ds['daily_sales'].quantile(0.75)
IQR = Q3-Q1

outliers = ds[(ds['daily_sales'] < Q1 - 1.5*IQR) | (ds['daily_sales'] > Q3 + 1.5*IQR)]
outliers
# Out:
#      Order Date  daily_sales  num_orders  AVG_ShippingDuration  year  month  \
# 9    2015-01-12    5624.3900           6                    74  2015      1
# 58   2015-03-18   28106.7160           3                     5  2015      3
# 77   2015-04-11    6693.7480           6                   173  2015      4
# 159  2015-07-25    8341.2900           2                     2  2015      7
# 169  2015-08-09   14228.4280          11                    69  2015      8
# ...         ...          ...         ...                   ...   ...    ...
# 1034 2018-11-13    6633.4202          14                     4  2018     11
# 1038 2018-11-17   13408.7928          11                     5  2018     11
# 1040 2018-11-19    7397.2720          15                     3  2018     11
# 1062 2018-12-22    7442.0210          12                     4  2018     12
# 1064 2018-12-24    6233.0540          11                     4  2018     12
#
#       day_of_week  is_weekend  Quarter  sales_lag_1  sales_lag_7  \
# 9               0           0        0     4637.816      119.888
# 58              2           0        1     3960.358      862.683
# 77              5           1        1      728.748      370.452
# 159             5           1        2     2613.184        9.510
# 169             6           1        3     3955.629      193.152
# ...           ...         ...      ...          ...          ...
# 1034            1           0        4     2025.035       46.960
# 1038            5           1        4     4755.234     4383.084
# 1040            0           0        4     1469.756     2025.035
# 1062            5           1        4     2140.940      306.888
# 1064            0           0        4     1926.776     2027.758
#
#       sales_lag_30  rolling_mean_7  rolling_mean_30  rolling_std_30
# 9              NaN     1607.103143              NaN             NaN
# 58         79.5600     1580.619429       773.259467     1073.013175
# 77         72.6320      744.187143      1822.817833     5089.806699
# 159       763.7920     1278.953143      1102.046887     1142.052609
# 169        87.1580     1254.902714      1336.412633     1708.245838
# ...            ...             ...              ...             ...
# 1034     1486.5760     1354.923286      2091.959173     3142.325881
# 1038       40.0320     3000.835600      2441.791113     3236.073082
# 1040      239.3580     4240.870857      2923.465140     3750.711629
# 1062     1815.2180     1607.694429      2527.359700     2746.117930
# 1064     6633.4202     2779.581143      2711.644500     2885.337731
#
# [70 rows x 15 columns]

# %%
outliers['daily_sales'].describe().T
# Out:
# count       70.000000
# mean      8391.948814
# std       3518.058948
# min       5418.022000
# 25%       6333.405000
# 50%       7322.472000
# 75%       8964.308500
# max      28106.716000
# Name: daily_sales, dtype: float64

# %% [markdown]
# ### ✅ 6. ADF test

# %%
from statsmodels.tsa.stattools import adfuller

# %%
result = adfuller(ds['daily_sales'])
print(f"ADF Statistic: {result[0]}")
print(f"p-value: {result[1]}")
# Out:
# ADF Statistic: -29.31472892034404
# p-value: 0.0

# %% [markdown]
# **✅ Phase 2 Complete: General overview, IQR and ADF test are now finished.**
# **Next Step — Phase 3: Let’s move on to preprocessing and modeling stage.**
# ## Phase 3: Preprocessing and Modeling
# - ✅ 7. Search Loop
# - ✅ 8. Best Model
# - ✅ 9. Model Evaluation

# %% [markdown]
# ### ✅ 7. Search Loop

# %%
# Machine learning models & tools
from sklearn.linear_model import Ridge, Lasso
from sklearn.ensemble import (
    RandomForestRegressor,
    GradientBoostingRegressor,
    ExtraTreesRegressor,
    AdaBoostRegressor
)
from sklearn.pipeline import Pipeline
from sklearn.impute import KNNImputer
from sklearn.model_selection import cross_validate, train_test_split

# Time-Series Aware CV
from sklearn.model_selection import TimeSeriesSplit

# Model evaluation metrics
from sklearn.metrics import mean_squared_error, r2_score

# Preprocessing
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

# %%
x = model_df.drop(['daily_sales','year','Order Date'],axis=1)
y = model_df['daily_sales']

# %% [markdown]
# #### 1. Scalers

# %%
scalers = [
    ('NoScaler','passthrough'),
    ('StandarScaler',StandardScaler()),
    ('MinMaxScaler',MinMaxScaler()),
    ("RobustScaler",RobustScaler())
]

# %% [markdown]
# #### 2. Models

# %%
models = [
    ('Ridge', Ridge(alpha=1.0)),
    ('Lasso', Lasso(alpha=0.01)),
    ('RandomForest', RandomForestRegressor(n_estimators=300, random_state=42)),
    ('GradientBoosting', GradientBoostingRegressor(n_estimators=300, learning_rate=0.05)),
    ('ExtraTrees', ExtraTreesRegressor(n_estimators=400, random_state=42)),
    ('AdaBoost', AdaBoostRegressor(n_estimators=200, learning_rate=0.05))
]

# %% [markdown]
# #### 3. For Loop

# %%
tscv = TimeSeriesSplit(n_splits=5)

# %%
results = []

for scaler in scalers:
    print(f"\nScaling with: {scaler[0]}")
    for model in models:
        print('_' * 60)
        print('Model:', model[0])

        steps = [
            ("Scaling",scaler[1]),
            ('model', model[1])
        ]

        pipeline = Pipeline(steps)

        cv_results = cross_validate(
            pipeline,
            x,
            y,
            cv=tscv,
            scoring={
                'MAE': 'neg_mean_absolute_error',
                'RMSE': 'neg_root_mean_squared_error'
            },
            return_train_score=True,
            n_jobs=-1
        )

        train_rmse = -cv_results['train_RMSE'].mean()
        test_rmse = -cv_results['test_RMSE'].mean()
        test_mae = -cv_results['test_MAE'].mean()

        print(f"Train RMSE: {train_rmse:.2f}")
        print(f"Test RMSE : {test_rmse:.2f}")
        print(f"Test MAE  : {test_mae:.2f}")

        results.append([
            scaler[0],
            model[0],
            train_rmse,
            test_rmse,
            test_mae
        ])

    print('_' * 60)
# Out:
# Scaling with: NoScaler
# ____________________________________________________________
# Model: Ridge
# Train RMSE: 2083.22
# Test RMSE : 1911.25
# Test MAE  : 1243.06
# ____________________________________________________________
# Model: Lasso
# Train RMSE: 2083.20
# Test RMSE : 1909.91
# Test MAE  : 1241.92
# ____________________________________________________________
# Model: RandomForest
# Train RMSE: 764.76
# Test RMSE : 2058.56
# Test MAE  : 1334.76
# ____________________________________________________________
# Model: GradientBoosting
# Train RMSE: 662.42
# Test RMSE : 2175.47
# Test MAE  : 1425.74
# ____________________________________________________________
# Model: ExtraTrees
# Train RMSE: 0.00
# Test RMSE : 2130.50
# Test MAE  : 1422.46
# ____________________________________________________________
# Model: AdaBoost
# Train RMSE: 1359.97
# Test RMSE : 1952.45
# Test MAE  : 1385.57
# ____________________________________________________________
#
# Scaling with: StandarScaler
# ____________________________________________________________
# Model: Ridge
# Train RMSE: 2083.23
# Test RMSE : 1906.53
# Test MAE  : 1238.91
# ____________________________________________________________
# Model: Lasso
# Train RMSE: 2083.20
# Test RMSE : 1909.88
# Test MAE  : 1241.90
# ____________________________________________________________
# Model: RandomForest
# Train RMSE: 764.79
# Test RMSE : 2058.38
# Test MAE  : 1334.82
# ____________________________________________________________
# Model: GradientBoosting
# Train RMSE: 662.42
# Test RMSE : 2183.52
# Test MAE  : 1434.37
# ____________________________________________________________
# Model: ExtraTrees
# Train RMSE: 0.00
# Test RMSE : 2130.50
# Test MAE  : 1422.46
# ____________________________________________________________
# Model: AdaBoost
# Train RMSE: 1351.24
# Test RMSE : 1945.84
# Test MAE  : 1376.86
# ____________________________________________________________
#
# Scaling with: MinMaxScaler
# ____________________________________________________________
# Model: Ridge
# Train RMSE: 2087.48
# Test RMSE : 1873.03
# Test MAE  : 1215.02
# ____________________________________________________________
# Model: Lasso
# Train RMSE: 2083.20
# Test RMSE : 1909.79
# Test MAE  : 1241.81
# ____________________________________________________________
# Model: RandomForest
# Train RMSE: 765.11
# Test RMSE : 2057.05
# Test MAE  : 1333.96
# ____________________________________________________________
# Model: GradientBoosting
# Train RMSE: 662.42
# Test RMSE : 2198.05
# Test MAE  : 1442.08
# ____________________________________________________________
# Model: ExtraTrees
# Train RMSE: 0.00
# Test RMSE : 2130.50
# Test MAE  : 1422.46
# ____________________________________________________________
# Model: AdaBoost
# Train RMSE: 1342.78
# Test RMSE : 1945.02
# Test MAE  : 1382.96
# ____________________________________________________________
#
# Scaling with: RobustScaler
# ____________________________________________________________
# Model: Ridge
# Train RMSE: 2083.34
# Test RMSE : 1901.48
# Test MAE  : 1234.97
# ____________________________________________________________
# Model: Lasso
# Train RMSE: 2083.20
# Test RMSE : 1909.87
# Test MAE  : 1241.88
# ____________________________________________________________
# Model: RandomForest
# Train RMSE: 764.77
# Test RMSE : 2054.94
# Test MAE  : 1332.75
# ____________________________________________________________
# Model: GradientBoosting
# Train RMSE: 662.42
# Test RMSE : 2193.70
# Test MAE  : 1436.59
# ____________________________________________________________
# Model: ExtraTrees
# Train RMSE: 0.00
# Test RMSE : 2130.50
# Test MAE  : 1422.46
# ____________________________________________________________
# Model: AdaBoost
# Train RMSE: 1365.63
# Test RMSE : 1960.93
# Test MAE  : 1400.53
# ____________________________________________________________

# %% [markdown]
# ### ✅ 8. Best Model
# $$
# \boxed{
# \text{Model: Ridge --> Train RMSE: 2087.48, Test RMSE : 1873.03, Test MAE  : 1215.02}
# }
# $$

# %% [markdown]
# #### 1. Train and Test Split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, 
                                                    test_size=0.15, 
                                                    random_state=42)

# %% [markdown]
# #### 2. Final Pipeline

# %%
steps = [
    ("Scaling",MinMaxScaler()),
    ('model', Ridge())
]

pipeline = Pipeline(steps)

# %%
pipeline
# Out:
# Pipeline(steps=[('Scaling', MinMaxScaler()), ('model', Ridge())])

# %% [markdown]
# #### 3. Training and prediction

# %%
r_model = pipeline.fit(x_train,y_train)

# %%
y_predict = r_model.predict(x_test)

# %% [markdown]
# ### ✅ 9. Model Evaluation

# %%
print("ٌRidge:")
print("MSE:", mean_squared_error(y_test,y_predict))
print("R2:", r2_score(y_test, y_predict))
print("-"*40)
# Out:
# ٌRidge:
# MSE: 3178654.098778318
# R2: 0.2386615615788572
# ----------------------------------------

# %%
plt.figure(figsize=(15,8))

plt.plot(y_test.values[:100], label="Actual Prices", marker='o')  

# Plot predicted values
plt.plot(y_predict[:100], label="Ridge Predicted Sales", marker='x')  
 

plt.title("Actual vs Predicted House Prices (Sample of 100)", fontsize=14)
plt.xlabel("Sample Index")
plt.ylabel("House Price")
plt.legend()
plt.show()
